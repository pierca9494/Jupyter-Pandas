# %% [markdown]
# Analisi Dati di Gruppo

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv('train.csv')

print("\nInformazioni Data Frame Car\n\n")

display(df.info())
# Out:
# Informazioni Data Frame Car
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188533 entries, 0 to 188532
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            188533 non-null  int64
#  1   brand         188533 non-null  object
#  2   model         188533 non-null  object
#  3   model_year    188533 non-null  int64
#  4   milage        188533 non-null  int64
#  5   fuel_type     183450 non-null  object
#  6   engine        188533 non-null  object
#  7   transmission  188533 non-null  object
#  8   ext_col       188533 non-null  object
#  9   int_col       188533 non-null  object
#  10  accident      186081 non-null  object
#  11  clean_title   167114 non-null  object
#  12  price         188533 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 18.7+ MB
# None

# %%
print("\nStampa elementi unici per colonna:\n\n")

print("Ci sono",len(set(df["brand"])),"brand diversi.")
print("Ci sono",len(set(df["model_year"])), "anni diversi.")
print("Ci sono",len(set(df["model"])),"modelli diversi.")
print("Ci sono",len(set(df["fuel_type"])), "fuel_type diversi.")
print("Ci sono",len(set(df["engine"])),"engine diversi.")
print("Ci sono",len(set(df["transmission"])), "trasmissioni diverse.")
print("Ci sono",len(set(df["ext_col"])),"ext_col diversi.")
print("Ci sono",len(set(df["int_col"])), "int_col diversi.")
print("Ci sono",len(set(df["accident"])), "accident diversi.")
print("Ci sono",len(set(df["clean_title"])),"clean_title diversi.")
print("Ci sono",len(set(df["price"])), "price diversi.")
# Out:
# Stampa elementi unici per colonna:
#
#
# Ci sono 57 brand diversi.
# Ci sono 34 anni diversi.
# Ci sono 1897 modelli diversi.
# Ci sono 8 fuel_type diversi.
# Ci sono 1117 engine diversi.
# Ci sono 52 trasmissioni diverse.
# Ci sono 319 ext_col diversi.
# Ci sono 156 int_col diversi.
# Ci sono 3 accident diversi.
# Ci sono 2 clean_title diversi.
# Ci sono 1569 price diversi.

# %%
#Rendiamo numerica la colonna Accident
df['accident'] = df['accident'].fillna(-1)
df["accident"].replace("None reported", 0, inplace = True)
df["accident"].replace("At least 1 accident or damage reported", 1, inplace = True)


#Rendiamo numerica la colonna clean_title

df['clean_title'] = df['clean_title'].fillna(0)
df["clean_title"].replace("Yes", 1, inplace = True)

#Pulizia colonna fuel_type

df['fuel_type'] = df['fuel_type'].fillna(-1)
# Out:
# /tmp/ipykernel_58305/585391148.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["accident"].replace("None reported", 0, inplace = True)
# /tmp/ipykernel_58305/585391148.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["accident"].replace("At least 1 accident or damage reported", 1, inplace = True)
# /tmp/ipykernel_58305/585391148.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["accident"].replace("At least 1 accident or damage reported", 1, inplace = True)
# /tmp/ipykernel_58305/585391148.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["clean_title"].replace("Yes", 1, inplace = True)
# /tmp/ipykernel_58305/585391148.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["clean_title"].replace("Yes", 1, inplace = True)

# %%
model_price_mean = df.groupby('model_year')['price'].mean()
print("Media del prezzo per anno modello:\n", model_price_mean)
# Out:
# Media del prezzo per anno modello:
#  model_year
# 1974    74124.083333
# 1992    26957.000000
# 1993    38091.871429
# 1994    50181.760870
# 1995    38205.872549
# 1996    17370.894180
# 1997    14586.419872
# 1998    13442.169096
# 1999    10702.705776
# 2000    13796.912186
# 2001    19227.459583
# 2002    21286.650546
# 2003    17021.920252
# 2004    19401.310506
# 2005    26376.852029
# 2006    18351.585288
# 2007    19449.327112
# 2008    20384.406711
# 2009    21522.417894
# 2010    19964.660449
# 2011    18084.812450
# 2012    19806.953897
# 2013    23437.342702
# 2014    24758.274866
# 2015    30974.878567
# 2016    33531.819655
# 2017    37943.234329
# 2018    47707.568722
# 2019    49375.295606
# 2020    61556.784074
# 2021    65893.857951
# 2022    72732.327005
# 2023    95707.912305
# 2024    78006.067901
# Name: price, dtype: float64

# %%
display(df[df["price"]<4000]["price"])
# Out:
# 28        3499
# 133       3900
# 305       3850
# 348       2300
# 394       3600
#           ...
# 187838    2500
# 187866    3950
# 187916    2300
# 188353    3499
# 188475    2500
# Name: price, Length: 1561, dtype: int64

# %%
def custom_range(start, stop):
    current = start
    while current < stop:
        if 2000 <= current < 10000:
            step = 2000
        elif 10000 <= current < 1000000:
            step = 100000
        elif 1000000 <= current <= 2954083:
            step = 1000000
        else:
            break  # Se fuori dai range specificati
        yield current
        current += step

df['PriceGroup'] = pd.cut(df['price'], bins= custom_range(2000,2954083), right= False)

price_group =  df.groupby('PriceGroup').agg(count_id =  ('id', 'count'),media_anno=('model_year', 'mean'), count_anni = ('model_year', 'mean'))

display(price_group)
sns.pairplot(price_group)
# Out:
# /tmp/ipykernel_58305/2536054174.py:17: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   price_group =  df.groupby('PriceGroup').agg(count_id =  ('id', 'count'),media_anno=('model_year', 'mean'), count_anni = ('model_year', 'mean'))
#                     count_id   media_anno   count_anni
# PriceGroup
# [2000, 4000)            1561  2006.582960  2006.582960
# [4000, 6000)            4447  2006.799640  2006.799640
# [6000, 8000)            6804  2007.664756  2007.664756
# [8000, 10000)           7382  2008.260092  2008.260092
# [10000, 110000)       159266  2016.657196  2016.657196
# [110000, 210000)        6094  2019.762225  2019.762225
# [210000, 310000)        1789  2019.581330  2019.581330
# [310000, 410000)         352  2019.019886  2019.019886
# [410000, 510000)         486  2019.329218  2019.329218
# [510000, 610000)          77  2019.246753  2019.246753
# [610000, 710000)          79  2019.962025  2019.962025
# [710000, 810000)          48  2020.458333  2020.458333
# [810000, 910000)           0          NaN          NaN
# [910000, 1010000)          0          NaN          NaN
# [1010000, 2010000)        98  2016.459184  2016.459184

# %%
plt.hist(price_group)
# Out:
# (array([[14.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#         [13.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [13.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.]]),
#  array([     0. ,  15926.6,  31853.2,  47779.8,  63706.4,  79633. ,
#          95559.6, 111486.2, 127412.8, 143339.4, 159266. ]),
#  <a list of 3 BarContainer objects>)

# %%
df['MilageGroup'] = pd.cut(df['milage'], bins= range(100,405000, 80000), right= False)

milage_group =  df.groupby('MilageGroup').agg(
    media_anno=('model_year', 'mean'),
    count_id = ('model_year', 'count'),
    
    price_milage = ('price', 'mean')
)

display(milage_group)
# plt.hist(price_group['milage_price'])
sns.pairplot(milage_group)
# Out:
# /tmp/ipykernel_58305/1741472744.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   milage_group =  df.groupby('MilageGroup').agg(
#                    media_anno  count_id  price_milage
# MilageGroup
# [100, 80100)      2018.149037    125365  56650.852614
# [80100, 160100)   2011.777114     53229  19562.490428
# [160100, 240100)  2008.351256      9355  12720.759487
# [240100, 320100)  2007.142857       532  16486.618421
# [320100, 400100)  2007.046512        43  23559.465116

# %%
df = df.drop(['model', 'ext_col', 'int_col', 'id',"PriceGroup", "MilageGroup"], axis=1)

def analyze_and_plot_fixed(dataframe, group_col, base_path):
    # Lista per DataFrame filtrati e correlazioni
    filtered_corr_list = []
    
    # Valori unici della colonna
    unique_values = dataframe[group_col].unique()
    
    for value in unique_values:
        # Filtra il DataFrame
        df_filtered = dataframe[dataframe[group_col] == value]
        
        if df_filtered.empty:
            continue  # Salta se il DataFrame è vuoto
        
        # Nome del gruppo
        group_name = str(df_filtered[group_col].iloc[0]).replace("/", "-")  # Gestione di caratteri speciali
        
        # Rimuovi le colonne non necessarie
        df_cleaned = df_filtered.drop(['brand', 'transmission', 'engine', 'fuel_type'], axis=1, errors='ignore')
        
        # Calcola la matrice di correlazione
        corr_matrix = df_cleaned.corr()
        
        # Filtra correlazioni significative
        filtered = corr_matrix.where(((corr_matrix > 0.3) | (corr_matrix < -0.3)) & (corr_matrix != 1)).stack()
        filtered_corr_list.append((f'{group_col} name: {group_name}\n', filtered))
        
        # Crea la directory per salvare le immagini
        save_path = os.path.join(base_path, group_col)
        os.makedirs(save_path, exist_ok=True)
        
        # # Plotta la heatmap
        # plt.figure(figsize=(10, 8))
        # sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
        # plt.title(f'Heatmap for {group_col}: {group_name}')
        
        # # Salva il grafico
        # plt.savefig(f'{save_path}/{group_name}_heatmap.png', bbox_inches='tight')
        # plt.close()  # Chiudi il grafico per evitare conflitti
        
    return filtered_corr_list

# Applica la funzione corretta
base_path = './image'
filtered_corr_trans = analyze_and_plot_fixed(df, 'transmission', base_path)
filtered_corr_brands = analyze_and_plot_fixed(df, 'brand', base_path)
filtered_corr_engines = analyze_and_plot_fixed(df, 'engine', base_path)
filtered_corr_fuels = analyze_and_plot_fixed(df, 'fuel_type', base_path)

# %%
# Visualizza i risultati
display(filtered_corr_brands)
print("\n\n---------------------\n\n")
display(filtered_corr_trans)
print("\n\n---------------------\n\n")
display(filtered_corr_engines)
print("\n\n---------------------\n\n")
display(filtered_corr_fuels)
# Out:
# [('brand name: MINI\n',
#   model_year  milage       -0.458579
#               price         0.534950
#   milage      model_year   -0.458579
#               price        -0.521113
#   price       model_year    0.534950
#               milage       -0.521113
#   dtype: float64),
#  ('brand name: Lincoln\n',
#   model_year  milage       -0.698952
#               price         0.429888
#   milage      model_year   -0.698952
#               price        -0.460630
#   price       model_year    0.429888
#               milage       -0.460630
#   dtype: float64),
#  ('brand name: Chevrolet\n',
#   model_year  milage       -0.630045
#   milage      model_year   -0.630045
#               accident      0.326432
#   accident    milage        0.326432
#   dtype: float64),
#  ('brand name: Genesis\n',
#   model_year  milage       -0.675972
#   milage      model_year   -0.675972
#   dtype: float64),
#  ('brand name: Mercedes-Benz\n',
#   model_year   milage        -0.655536
#                clean_title   -0.308800
#   milage       model_year    -0.655536
#   clean_title  model_year    -0.308800
#   dtype: float64),
#  ('brand name: Audi\n',
#   model_year   milage        -0.703966
#                clean_title   -0.403918
#   milage       model_year    -0.703966
#                clean_title    0.364385
#                price         -0.339701
#   clean_title  model_year    -0.403918
#                milage         0.364385
#   price        milage        -0.339701
#   dtype: float64),
#  ('brand name: Ford\n',
#   model_year  milage       -0.669967
#   milage      model_year   -0.669967
#   dtype: float64),
#  ('brand name: BMW\n',
#   model_year  milage       -0.674320
#               price         0.341063
#   milage      model_year   -0.674320
#               price        -0.386157
#   price       model_year    0.341063
#               milage       -0.386157
#   dtype: float64),
#  ('brand name: Tesla\n',
#   model_year  milage       -0.619798
#   milage      model_year   -0.619798
#   dtype: float64),
#  ('brand name: Cadillac\n',
#   model_year  milage       -0.650689
#   milage      model_year   -0.650689
#   dtype: float64),
#  ('brand name: Land\n',
#   model_year  milage       -0.767152
#   milage      model_year   -0.767152
#               accident      0.303053
#   accident    milage        0.303053
#   dtype: float64),
#  ('brand name: GMC\n',
#   model_year  milage       -0.690151
#   milage      model_year   -0.690151
#   dtype: float64),
#  ('brand name: Toyota\n',
#   model_year   milage        -0.697926
#                clean_title   -0.320321
#   milage       model_year    -0.697926
#   clean_title  model_year    -0.320321
#   dtype: float64),
#  ('brand name: Hyundai\n',
#   model_year   milage        -0.677759
#                clean_title   -0.421746
#   milage       model_year    -0.677759
#                clean_title    0.357665
#   clean_title  model_year    -0.421746
#                milage         0.357665
#   dtype: float64),
#  ('brand name: Volvo\n',
#   model_year  milage       -0.600466
#               price         0.406699
#   milage      model_year   -0.600466
#               price        -0.438068
#   price       model_year    0.406699
#               milage       -0.438068
#   dtype: float64),
#  ('brand name: Volkswagen\n',
#   model_year  milage       -0.579730
#               price         0.374359
#   milage      model_year   -0.579730
#               price        -0.434360
#   price       model_year    0.374359
#               milage       -0.434360
#   dtype: float64),
#  ('brand name: Buick\n',
#   model_year   milage        -0.636786
#                clean_title   -0.329273
#                price          0.381457
#   milage       model_year    -0.636786
#                clean_title    0.337726
#                price         -0.350097
#   clean_title  model_year    -0.329273
#                milage         0.337726
#   price        model_year     0.381457
#                milage        -0.350097
#   dtype: float64),
#  ('brand name: Rivian\n',
#   model_year   milage        -0.468303
#   milage       model_year    -0.468303
#   accident     clean_title    0.474255
#   clean_title  accident       0.474255
#   dtype: float64),
#  ('brand name: RAM\n',
#   model_year  milage       -0.681949
#   milage      model_year   -0.681949
#   dtype: float64),
#  ('brand name: Hummer\n',
#   model_year  price         0.321702
#   milage      price        -0.310059
#   price       model_year    0.321702
#               milage       -0.310059
#   dtype: float64),
#  ('brand name: Alfa\n',
#   model_year  milage       -0.678682
#               price         0.356567
#   milage      model_year   -0.678682
#               price        -0.318510
#   price       model_year    0.356567
#               milage       -0.318510
#   dtype: float64),
#  ('brand name: INFINITI\n',
#   model_year  milage       -0.631706
#   milage      model_year   -0.631706
#   dtype: float64),
#  ('brand name: Jeep\n',
#   model_year   milage        -0.779154
#                accident      -0.333123
#                clean_title   -0.334494
#                price          0.453267
#   milage       model_year    -0.779154
#                accident       0.389004
#                clean_title    0.310250
#                price         -0.468507
#   accident     model_year    -0.333123
#                milage         0.389004
#   clean_title  model_year    -0.334494
#                milage         0.310250
#   price        model_year     0.453267
#                milage        -0.468507
#   dtype: float64),
#  ('brand name: Porsche\n',
#   model_year  milage       -0.552357
#   milage      model_year   -0.552357
#   dtype: float64),
#  ('brand name: McLaren\n', Series([], dtype: float64)),
#  ('brand name: Honda\n',
#   model_year   milage        -0.591168
#                clean_title   -0.398457
#   milage       model_year    -0.591168
#                clean_title    0.356960
#   clean_title  model_year    -0.398457
#                milage         0.356960
#   dtype: float64),
#  ('brand name: Lexus\n',
#   model_year   milage        -0.727936
#                accident      -0.319644
#                clean_title   -0.341249
#   milage       model_year    -0.727936
#                accident       0.350940
#                clean_title    0.324147
#   accident     model_year    -0.319644
#                milage         0.350940
#   clean_title  model_year    -0.341249
#                milage         0.324147
#   dtype: float64),
#  ('brand name: Dodge\n',
#   model_year  milage       -0.694481
#               accident     -0.326286
#   milage      model_year   -0.694481
#               accident      0.383372
#               price        -0.324846
#   accident    model_year   -0.326286
#               milage        0.383372
#   price       milage       -0.324846
#   dtype: float64),
#  ('brand name: Nissan\n',
#   model_year   milage        -0.582365
#                clean_title   -0.321707
#                price          0.342261
#   milage       model_year    -0.582365
#                price         -0.397418
#   clean_title  model_year    -0.321707
#   price        model_year     0.342261
#                milage        -0.397418
#   dtype: float64),
#  ('brand name: Jaguar\n',
#   model_year  milage       -0.476197
#   milage      model_year   -0.476197
#   dtype: float64),
#  ('brand name: Acura\n',
#   model_year   milage        -0.706921
#                clean_title   -0.476400
#                price          0.468285
#   milage       model_year    -0.706921
#                accident       0.362991
#                clean_title    0.414091
#                price         -0.476469
#   accident     milage         0.362991
#   clean_title  model_year    -0.476400
#                milage         0.414091
#   price        model_year     0.468285
#                milage        -0.476469
#   dtype: float64),
#  ('brand name: Kia\n',
#   model_year   milage        -0.760700
#                accident      -0.307384
#                clean_title   -0.350654
#                price          0.382272
#   milage       model_year    -0.760700
#                accident       0.332134
#                clean_title    0.311900
#                price         -0.382357
#   accident     model_year    -0.307384
#                milage         0.332134
#   clean_title  model_year    -0.350654
#                milage         0.311900
#   price        model_year     0.382272
#                milage        -0.382357
#   dtype: float64),
#  ('brand name: Mitsubishi\n',
#   model_year  milage       -0.306686
#   milage      model_year   -0.306686
#   dtype: float64),
#  ('brand name: Rolls-Royce\n',
#   model_year  milage       -0.453088
#   milage      model_year   -0.453088
#   dtype: float64),
#  ('brand name: Maserati\n',
#   model_year  milage       -0.605156
#               accident     -0.308531
#               price         0.324414
#   milage      model_year   -0.605156
#               price        -0.339195
#   accident    model_year   -0.308531
#   price       model_year    0.324414
#               milage       -0.339195
#   dtype: float64),
#  ('brand name: Pontiac\n', Series([], dtype: float64)),
#  ('brand name: Saturn\n',
#   model_year  milage       -0.406381
#               price         0.305041
#   milage      model_year   -0.406381
#               price        -0.513604
#   price       model_year    0.305041
#               milage       -0.513604
#   dtype: float64),
#  ('brand name: Bentley\n',
#   model_year   milage        -0.583488
#   milage       model_year    -0.583488
#   accident     clean_title    0.310130
#   clean_title  accident       0.310130
#   dtype: float64),
#  ('brand name: Mazda\n',
#   model_year  milage       -0.61121
#   milage      model_year   -0.61121
#   dtype: float64),
#  ('brand name: Subaru\n',
#   model_year  milage       -0.553708
#               price         0.425806
#   milage      model_year   -0.553708
#               price        -0.486116
#   price       model_year    0.425806
#               milage       -0.486116
#   dtype: float64),
#  ('brand name: Ferrari\n',
#   model_year  milage       -0.525155
#   milage      model_year   -0.525155
#   dtype: float64),
#  ('brand name: Aston\n',
#   model_year  milage       -0.520985
#   milage      model_year   -0.520985
#   dtype: float64),
#  ('brand name: Lamborghini\n',
#   model_year   milage        -0.415872
#                clean_title   -0.352557
#   milage       model_year    -0.415872
#   clean_title  model_year    -0.352557
#   dtype: float64),
#  ('brand name: Chrysler\n',
#   model_year  milage       -0.593726
#   milage      model_year   -0.593726
#   dtype: float64),
#  ('brand name: Lucid\n',
#   model_year   milage        -0.463354
#                price          0.363247
#   milage       model_year    -0.463354
#   accident     clean_title    0.408597
#   clean_title  accident       0.408597
#   price        model_year     0.363247
#   dtype: float64),
#  ('brand name: Lotus\n',
#   model_year   milage        -0.456054
#                accident      -0.472856
#                price          0.652633
#   milage       model_year    -0.456054
#                accident       0.319871
#                price         -0.546601
#   accident     model_year    -0.472856
#                milage         0.319871
#                clean_title    0.306814
#   clean_title  accident       0.306814
#   price        model_year     0.652633
#                milage        -0.546601
#   dtype: float64),
#  ('brand name: Scion\n',
#   model_year  milage       -0.310814
#               price         0.465434
#   milage      model_year   -0.310814
#               price        -0.478610
#   price       model_year    0.465434
#               milage       -0.478610
#   dtype: float64),
#  ('brand name: smart\n',
#   model_year   milage        -0.746287
#                accident      -0.450910
#                clean_title   -0.998443
#                price          0.997741
#   milage       model_year    -0.746287
#                accident       0.930624
#                clean_title    0.782257
#                price         -0.789316
#   accident     model_year    -0.450910
#                milage         0.930624
#                clean_title    0.500000
#                price         -0.509851
#   clean_title  model_year    -0.998443
#                milage         0.782257
#                accident       0.500000
#                price         -0.999935
#   price        model_year     0.997741
#                milage        -0.789316
#                accident      -0.509851
#                clean_title   -0.999935
#   dtype: float64),
#  ('brand name: Karma\n',
#   model_year   milage        -0.781564
#                accident      -0.594453
#                clean_title   -0.513144
#                price          0.539630
#   milage       model_year    -0.781564
#                accident       0.576803
#                clean_title    0.333918
#                price         -0.515631
#   accident     model_year    -0.594453
#                milage         0.576803
#                price         -0.367836
#   clean_title  model_year    -0.513144
#                milage         0.333918
#                price         -0.354023
#   price        model_year     0.539630
#                milage        -0.515631
#                accident      -0.367836
#                clean_title   -0.354023
#   dtype: float64),
#  ('brand name: Plymouth\n',
#   milage    accident   -0.418250
#             price      -0.339761
#   accident  milage     -0.418250
#   price     milage     -0.339761
#   dtype: float64),
#  ('brand name: Suzuki\n',
#   model_year   clean_title   -0.643569
#   milage       accident       0.331885
#   accident     milage         0.331885
#                clean_title    0.333333
#                price         -0.329135
#   clean_title  model_year    -0.643569
#                accident       0.333333
#                price         -0.659745
#   price        accident      -0.329135
#                clean_title   -0.659745
#   dtype: float64),
#  ('brand name: FIAT\n',
#   model_year   milage        -0.592601
#                price          0.479372
#   milage       model_year    -0.592601
#                price         -0.369788
#   accident     clean_title    0.540128
#   clean_title  accident       0.540128
#   price        model_year     0.479372
#                milage        -0.369788
#   dtype: float64),
#  ('brand name: Saab\n',
#   model_year  milage       -0.535001
#               price         0.583141
#   milage      model_year   -0.535001
#               price        -0.508817
#   accident    price        -0.377665
#   price       model_year    0.583141
#               milage       -0.508817
#               accident     -0.377665
#   dtype: float64),
#  ('brand name: Bugatti\n',
#   model_year   clean_title   -0.708559
#                price         -0.386639
#   milage       clean_title    0.340505
#   clean_title  model_year    -0.708559
#                milage         0.340505
#   price        model_year    -0.386639
#   dtype: float64),
#  ('brand name: Mercury\n',
#   accident     clean_title    0.468298
#   clean_title  accident       0.468298
#   dtype: float64),
#  ('brand name: Polestar\n',
#   model_year   milage        -0.811010
#                clean_title   -0.608627
#                price          0.437134
#   milage       model_year    -0.811010
#                clean_title    0.527372
#                price         -0.502653
#   accident     clean_title    0.353553
#   clean_title  model_year    -0.608627
#                milage         0.527372
#                accident       0.353553
#                price         -0.390173
#   price        model_year     0.437134
#                milage        -0.502653
#                clean_title   -0.390173
#   dtype: float64),
#  ('brand name: Maybach\n',
#   model_year  price        -0.492960
#   milage      accident      0.948776
#               price        -0.688157
#   accident    milage        0.948776
#               price        -0.882148
#   price       model_year   -0.492960
#               milage       -0.688157
#               accident     -0.882148
#   dtype: float64)]
# ---------------------
# [('transmission name: A-T\n',
#   model_year  milage       -0.668760
#               price         0.300510
#   milage      model_year   -0.668760
#               accident      0.304263
#               price        -0.336625
#   accident    milage        0.304263
#   price       model_year    0.300510
#               milage       -0.336625
#   dtype: float64),
#  ('transmission name: Transmission w-Dual Shift Mode\n',
#   model_year  milage       -0.609544
#   milage      model_year   -0.609544
#   dtype: float64),
#  ('transmission name: 7-Speed A-T\n',
#   model_year   milage        -0.515011
#   milage       model_year    -0.515011
#   accident     clean_title    0.308521
#   clean_title  accident       0.308521
#   dtype: float64),
#  ('transmission name: 8-Speed A-T\n',
#   model_year   milage        -0.648887
#   milage       model_year    -0.648887
#   accident     clean_title    0.329528
#   clean_title  accident       0.329528
#   dtype: float64),
#  ('transmission name: 10-Speed Automatic\n',
#   model_year  milage       -0.456406
#   milage      model_year   -0.456406
#   dtype: float64),
#  ('transmission name: 1-Speed A-T\n',
#   model_year   milage        -0.601679
#                price          0.324240
#   milage       model_year    -0.601679
#                price         -0.322767
#   accident     clean_title    0.421006
#   clean_title  accident       0.421006
#   price        model_year     0.324240
#                milage        -0.322767
#   dtype: float64),
#  ('transmission name: 6-Speed A-T\n',
#   model_year  milage       -0.439683
#   milage      model_year   -0.439683
#   dtype: float64),
#  ('transmission name: 10-Speed A-T\n',
#   model_year   milage        -0.583382
#   milage       model_year    -0.583382
#   accident     clean_title    0.350956
#   clean_title  accident       0.350956
#   dtype: float64),
#  ('transmission name: 9-Speed A-T\n',
#   model_year  milage       -0.612443
#   milage      model_year   -0.612443
#   dtype: float64),
#  ('transmission name: 8-Speed Automatic\n',
#   model_year  milage       -0.512394
#   milage      model_year   -0.512394
#   dtype: float64),
#  ('transmission name: 9-Speed Automatic\n',
#   model_year  milage       -0.456383
#   milage      model_year   -0.456383
#   dtype: float64),
#  ('transmission name: 5-Speed A-T\n',
#   model_year  milage       -0.306885
#   milage      model_year   -0.306885
#   dtype: float64),
#  ('transmission name: Automatic\n',
#   model_year  milage       -0.451561
#   milage      model_year   -0.451561
#   dtype: float64),
#  ('transmission name: 7-Speed Automatic with Auto-Shift\n',
#   model_year  milage       -0.393604
#   milage      model_year   -0.393604
#   dtype: float64),
#  ('transmission name: CVT Transmission\n',
#   model_year  milage       -0.632821
#               price         0.512982
#   milage      model_year   -0.632821
#               price        -0.521402
#   price       model_year    0.512982
#               milage       -0.521402
#   dtype: float64),
#  ('transmission name: 5-Speed M-T\n', Series([], dtype: float64)),
#  ('transmission name: M-T\n',
#   model_year   milage        -0.513049
#                price          0.359917
#   milage       model_year    -0.513049
#                price         -0.418045
#   accident     clean_title    0.395864
#   clean_title  accident       0.395864
#   price        model_year     0.359917
#                milage        -0.418045
#   dtype: float64),
#  ('transmission name: 6-Speed M-T\n',
#   model_year  milage       -0.413417
#   milage      model_year   -0.413417
#   dtype: float64),
#  ('transmission name: 6-Speed Automatic\n',
#   model_year  milage       -0.551204
#   milage      model_year   -0.551204
#   dtype: float64),
#  ('transmission name: 4-Speed Automatic\n',
#   model_year  milage       -0.542277
#   milage      model_year   -0.542277
#   dtype: float64),
#  ('transmission name: 7-Speed M-T\n',
#   model_year   milage        -0.348852
#   milage       model_year    -0.348852
#   accident     clean_title    0.557245
#   clean_title  accident       0.557245
#   dtype: float64),
#  ('transmission name: 2-Speed A-T\n',
#   model_year  milage       -0.750287
#               accident     -0.558127
#               price         0.524320
#   milage      model_year   -0.750287
#               accident      0.516360
#               price        -0.499442
#   accident    model_year   -0.558127
#               milage        0.516360
#               price        -0.423327
#   price       model_year    0.524320
#               milage       -0.499442
#               accident     -0.423327
#   dtype: float64),
#  ('transmission name: 1-Speed Automatic\n',
#   model_year  milage       -0.42808
#   milage      model_year   -0.42808
#   dtype: float64),
#  ('transmission name: Automatic CVT\n',
#   model_year  milage       -0.647047
#   milage      model_year   -0.647047
#   dtype: float64),
#  ('transmission name: 4-Speed A-T\n', Series([], dtype: float64)),
#  ('transmission name: 6-Speed Manual\n',
#   model_year  milage       -0.406307
#   milage      model_year   -0.406307
#   dtype: float64),
#  ('transmission name: Transmission Overdrive Switch\n',
#   model_year  price         0.508134
#   milage      price        -0.418206
#   price       model_year    0.508134
#               milage       -0.418206
#   dtype: float64),
#  ('transmission name: 8-Speed Automatic with Auto-Shift\n',
#   model_year  milage       -0.460452
#   milage      model_year   -0.460452
#   dtype: float64),
#  ('transmission name: 7-Speed Manual\n',
#   model_year  milage       -0.307987
#   milage      model_year   -0.307987
#               price        -0.359823
#   price       milage       -0.359823
#   dtype: float64),
#  ('transmission name: 7-Speed Automatic\n',
#   model_year  milage       -0.482614
#   milage      model_year   -0.482614
#   dtype: float64),
#  ('transmission name: 9-Speed Automatic with Auto-Shift\n',
#   model_year  price         0.326920
#   milage      accident     -0.510163
#   accident    milage       -0.510163
#   price       model_year    0.326920
#   dtype: float64),
#  ('transmission name: 6-Speed Automatic with Auto-Shift\n',
#   model_year  milage       -0.504118
#               price         0.333040
#   milage      model_year   -0.504118
#               price        -0.401411
#   price       model_year    0.333040
#               milage       -0.401411
#   dtype: float64),
#  ('transmission name: 6-Speed Electronically Controlled Automatic with O\n',
#   model_year  price         0.352624
#   price       model_year    0.352624
#   dtype: float64),
#  ('transmission name: F\n',
#   model_year   milage        -0.702978
#                accident      -0.556704
#                clean_title   -0.494359
#   milage       model_year    -0.702978
#   accident     model_year    -0.556704
#                clean_title    0.371753
#   clean_title  model_year    -0.494359
#                accident       0.371753
#   dtype: float64),
#  ('transmission name: CVT-F\n',
#   model_year  milage       -0.729140
#               price         0.693476
#   milage      model_year   -0.729140
#               price        -0.606410
#   accident    price        -0.378885
#   price       model_year    0.693476
#               milage       -0.606410
#               accident     -0.378885
#   dtype: float64),
#  ('transmission name: 8-Speed Manual\n',
#   model_year  milage       -0.439293
#   milage      model_year   -0.439293
#   dtype: float64),
#  ('transmission name: Manual\n',
#   model_year   clean_title   -0.514347
#   milage       accident       0.453673
#                price         -0.332655
#   accident     milage         0.453673
#                clean_title    0.337978
#   clean_title  model_year    -0.514347
#                accident       0.337978
#   price        milage        -0.332655
#   dtype: float64),
#  ('transmission name: –\n',
#   model_year  milage       -0.384965
#   milage      model_year   -0.384965
#   dtype: float64),
#  ('transmission name: 2\n',
#   model_year   milage        -0.613105
#                clean_title   -0.424396
#   milage       model_year    -0.613105
#   clean_title  model_year    -0.424396
#   dtype: float64),
#  ('transmission name: 6 Speed At-Mt\n',
#   model_year  milage       -0.480713
#               price         0.620973
#   milage      model_year   -0.480713
#               accident      0.428734
#               price        -0.417473
#   accident    milage        0.428734
#   price       model_year    0.620973
#               milage       -0.417473
#   dtype: float64),
#  ('transmission name: 5-Speed Automatic\n', Series([], dtype: float64)),
#  ('transmission name: 2-Speed Automatic\n',
#   model_year   milage        -0.632030
#                accident      -0.480734
#   milage       model_year    -0.632030
#                accident       0.687084
#                clean_title    0.318441
#                price         -0.437281
#   accident     model_year    -0.480734
#                milage         0.687084
#                clean_title    0.319438
#   clean_title  milage         0.318441
#                accident       0.319438
#   price        milage        -0.437281
#   dtype: float64),
#  ('transmission name: 8-SPEED A-T\n',
#   model_year   milage        -0.936958
#                clean_title   -0.419573
#                price          0.650465
#   milage       model_year    -0.936958
#                price         -0.645122
#   clean_title  model_year    -0.419573
#                price         -0.317156
#   price        model_year     0.650465
#                milage        -0.645122
#                clean_title   -0.317156
#   dtype: float64),
#  ('transmission name: 7-Speed\n',
#   model_year   clean_title   -0.458764
#   accident     price          0.577025
#   clean_title  model_year    -0.458764
#   price        accident       0.577025
#   dtype: float64),
#  ('transmission name: Variable\n',
#   model_year  milage       -0.544785
#               price         0.451134
#   milage      model_year   -0.544785
#               price        -0.354081
#   price       model_year    0.451134
#               milage       -0.354081
#   dtype: float64),
#  ('transmission name: Single-Speed Fixed Gear\n',
#   model_year   clean_title   -0.361158
#   clean_title  model_year    -0.361158
#                price          0.341458
#   price        clean_title    0.341458
#   dtype: float64),
#  ('transmission name: 8-SPEED AT\n',
#   model_year   milage        -0.457212
#                accident       0.318788
#   milage       model_year    -0.457212
#   accident     model_year     0.318788
#   clean_title  price          0.345657
#   price        clean_title    0.345657
#   dtype: float64),
#  ('transmission name: 10-Speed Automatic with Overdrive\n',
#   model_year   milage        -0.463854
#                clean_title   -0.391220
#   milage       model_year    -0.463854
#                clean_title    0.394868
#   clean_title  model_year    -0.391220
#                milage         0.394868
#   dtype: float64),
#  ('transmission name: 7-Speed DCT Automatic\n',
#   model_year   milage        -0.450584
#                accident      -0.456963
#                price          0.421522
#   milage       model_year    -0.450584
#                accident       0.435201
#                clean_title    0.303190
#   accident     model_year    -0.456963
#                milage         0.435201
#                clean_title    0.316228
#   clean_title  milage         0.303190
#                accident       0.316228
#   price        model_year     0.421522
#   dtype: float64),
#  ('transmission name: SCHEDULED FOR OR IN PRODUCTION\n',
#   model_year   clean_title   -0.539360
#                price          0.489288
#   clean_title  model_year    -0.539360
#                price         -0.542319
#   price        model_year     0.489288
#                clean_title   -0.542319
#   dtype: float64),
#  ('transmission name: 6-Speed\n',
#   model_year   milage        -0.566235
#                clean_title   -0.363820
#                price          0.361382
#   milage       model_year    -0.566235
#                price         -0.349319
#   clean_title  model_year    -0.363820
#   price        model_year     0.361382
#                milage        -0.349319
#   dtype: float64),
#  ('transmission name: 6 Speed Mt\n',
#   model_year  milage       -0.716327
#               accident      0.613939
#               price         0.540076
#   milage      model_year   -0.716327
#               accident     -0.350505
#               price        -0.603077
#   accident    model_year    0.613939
#               milage       -0.350505
#   price       model_year    0.540076
#               milage       -0.603077
#   dtype: float64)]
# ---------------------
# [('engine name: 172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel\n',
#   Series([], dtype: float64)),
#  ('engine name: 252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel\n',
#   milage  price    -0.340322
#   price   milage   -0.340322
#   dtype: float64),
#  ('engine name: 320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capability\n',
#   Series([], dtype: float64)),
#  ('engine name: 420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year   milage        -0.470329
#                price          0.424914
#   milage       model_year    -0.470329
#                price         -0.440404
#   accident     clean_title    0.344751
#   clean_title  accident       0.344751
#   price        model_year     0.424914
#                milage        -0.440404
#   dtype: float64),
#  ('engine name: 208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.725103
#               price         0.454147
#   milage      model_year   -0.725103
#               price        -0.433395
#   price       model_year    0.454147
#               milage       -0.433395
#   dtype: float64),
#  ('engine name: 252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.571973
#               price         0.459505
#   milage      model_year   -0.571973
#               price        -0.460505
#   price       model_year    0.459505
#               milage       -0.460505
#   dtype: float64),
#  ('engine name: 333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.443831
#               price         0.350329
#   milage      model_year   -0.443831
#               price        -0.406341
#   price       model_year    0.350329
#               milage       -0.406341
#   dtype: float64),
#  ('engine name: 355.0HP 5.3L 8 Cylinder Engine Flex Fuel Capability\n',
#   model_year  milage       -0.420479
#               price         0.449809
#   milage      model_year   -0.420479
#               price        -0.302125
#   price       model_year    0.449809
#               milage       -0.302125
#   dtype: float64),
#  ('engine name: 2.7L V6 24V PDI DOHC Twin Turbo\n',
#   model_year   milage        -0.385932
#   milage       model_year    -0.385932
#   accident     clean_title    0.389429
#   clean_title  accident       0.389429
#   dtype: float64),
#  ('engine name: 425.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.518544
#   milage      model_year   -0.518544
#   dtype: float64),
#  ('engine name: 312.0HP 3.6L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.303598
#               price         0.466792
#   milage      model_year   -0.303598
#               price        -0.457447
#   price       model_year    0.466792
#               milage       -0.457447
#   dtype: float64),
#  ('engine name: Electric Motor Electric Fuel System\n',
#   model_year   milage        -0.619612
#   milage       model_year    -0.619612
#   accident     clean_title    0.311685
#   clean_title  accident       0.311685
#   dtype: float64),
#  ('engine name: 420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.650915
#   milage      model_year   -0.650915
#   dtype: float64),
#  ('engine name: 523.0HP 4.4L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year   milage        -0.507011
#   milage       model_year    -0.507011
#   accident     clean_title    0.613769
#   clean_title  accident       0.613769
#   dtype: float64),
#  ('engine name: 503.0HP 4.0L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.395713
#   milage      model_year   -0.395713
#               price        -0.302417
#   price       milage       -0.302417
#   dtype: float64),
#  ('engine name: 395.0HP 3.0L Straight 6 Cylinder Engine Gasoline-Mild Electric Hybrid\n',
#   model_year   milage        -0.543243
#   milage       model_year    -0.543243
#   accident     clean_title    0.541517
#   clean_title  accident       0.541517
#   dtype: float64),
#  ('engine name: 310.0HP 4.6L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.406662
#               price         0.441609
#   milage      model_year   -0.406662
#               price        -0.500850
#   price       model_year    0.441609
#               milage       -0.500850
#   dtype: float64),
#  ('engine name: 469.0HP 4.0L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year   milage        -0.502129
#   milage       model_year    -0.502129
#   accident     clean_title    0.391887
#   clean_title  accident       0.391887
#   dtype: float64),
#  ('engine name: 5.2L V10 40V PDI DOHC\n',
#   model_year  milage       -0.400043
#   milage      model_year   -0.400043
#   dtype: float64),
#  ('engine name: 429.0HP 5.0L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.473613
#               price         0.464395
#   milage      model_year   -0.473613
#               price        -0.578281
#   price       model_year    0.464395
#               milage       -0.578281
#   dtype: float64),
#  ('engine name: 210.0HP 3.7L V6 Cylinder Engine Gasoline Fuel\n',
#   Series([], dtype: float64)),
#  ('engine name: 335.0HP 3.0L V6 Cylinder Engine Gasoline-Mild Electric Hybrid\n',
#   model_year   milage        -0.612424
#   milage       model_year    -0.612424
#   accident     clean_title    0.355810
#   clean_title  accident       0.355810
#   dtype: float64),
#  ('engine name: 316.0HP 2.0L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.423673
#               price         0.509253
#   milage      model_year   -0.423673
#               accident      0.306982
#               price        -0.598838
#   accident    milage        0.306982
#   price       model_year    0.509253
#               milage       -0.598838
#   dtype: float64),
#  ('engine name: 381.0HP 5.7L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.602076
#               price         0.334160
#   milage      model_year   -0.602076
#               price        -0.329770
#   price       model_year    0.334160
#               milage       -0.329770
#   dtype: float64),
#  ('engine name: 450.0HP 6.7L 8 Cylinder Engine Diesel Fuel\n',
#   model_year  milage       -0.388422
#   milage      model_year   -0.388422
#   dtype: float64),
#  ('engine name: 236.0HP 4.0L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.441475
#               price         0.404734
#   milage      model_year   -0.441475
#               price        -0.482766
#   price       model_year    0.404734
#               milage       -0.482766
#   dtype: float64),
#  ('engine name: 211.0HP 2.0L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.464587
#               price         0.401503
#   milage      model_year   -0.464587
#               price        -0.437988
#   price       model_year    0.401503
#               milage       -0.437988
#   dtype: float64),
#  ('engine name: 220.0HP 2.0L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.48358
#   milage      model_year   -0.48358
#   dtype: float64),
#  ('engine name: 255.0HP 2.0L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.618007
#   milage      model_year   -0.618007
#   dtype: float64),
#  ('engine name: 518.0HP Electric Motor Electric Fuel System\n',
#   model_year  milage       -0.527479
#   milage      model_year   -0.527479
#               price        -0.307107
#   price       milage       -0.307107
#   dtype: float64),
#  ('engine name: 268.0HP 3.5L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.368581
#   milage      model_year   -0.368581
#   dtype: float64),
#  ('engine name: 174.0HP 2.8L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year  price         0.431459
#   milage      price        -0.550133
#   price       model_year    0.431459
#               milage       -0.550133
#   dtype: float64),
#  ('engine name: 240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel\n',
#   milage  price    -0.38399
#   price   milage   -0.38399
#   dtype: float64),
#  ('engine name: 248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.552813
#               price         0.313193
#   milage      model_year   -0.552813
#               price        -0.311120
#   price       model_year    0.313193
#               milage       -0.311120
#   dtype: float64),
#  ('engine name: 563.0HP 5.5L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.38708
#   milage      model_year   -0.38708
#   dtype: float64),
#  ('engine name: 241.0HP 2.0L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.574651
#               price         0.310167
#   milage      model_year   -0.574651
#               price        -0.304068
#   price       model_year    0.310167
#               milage       -0.304068
#   dtype: float64),
#  ('engine name: 3.6L V6 24V GDI DOHC\n',
#   model_year  milage       -0.463251
#   milage      model_year   -0.463251
#   dtype: float64),
#  ('engine name: 230.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel\n',
#   milage  price    -0.348343
#   price   milage   -0.348343
#   dtype: float64),
#  ('engine name: 430.0HP 6.2L 8 Cylinder Engine Gasoline Fuel\n',
#   Series([], dtype: float64)),
#  ('engine name: 4.0L V8 32V GDI DOHC Twin Turbo\n',
#   model_year  milage       -0.498986
#   milage      model_year   -0.498986
#   dtype: float64),
#  ('engine name: 835.0HP Electric Motor Electric Fuel System\n',
#   model_year   milage        -0.447857
#   milage       model_year    -0.447857
#   accident     clean_title    0.601097
#   clean_title  accident       0.601097
#   dtype: float64),
#  ('engine name: 5.7L V8 16V MPFI OHV\n',
#   model_year  milage       -0.539305
#   milage      model_year   -0.539305
#   dtype: float64),
#  ('engine name: 300.0HP 5.4L 8 Cylinder Engine Gasoline Fuel\n',
#   Series([], dtype: float64)),
#  ('engine name: 310.0HP 6.8L 10 Cylinder Engine Gasoline Fuel\n',
#   model_year  price         0.332506
#   milage      price        -0.444721
#   price       model_year    0.332506
#               milage       -0.444721
#   dtype: float64),
#  ('engine name: 280.0HP 2.0L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year   milage        -0.673418
#                price          0.395379
#   milage       model_year    -0.673418
#                price         -0.347630
#   accident     clean_title    0.488322
#   clean_title  accident       0.488322
#   price        model_year     0.395379
#                milage        -0.347630
#   dtype: float64),
#  ('engine name: 295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.683803
#               price         0.456096
#   milage      model_year   -0.683803
#               price        -0.420131
#   price       model_year    0.456096
#               milage       -0.420131
#   dtype: float64),
#  ('engine name: Dual Motor - Standard\n',
#   model_year  milage       -0.43167
#   milage      model_year   -0.43167
#   dtype: float64),
#  ('engine name: 348.0HP 3.8L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year   milage        -0.442418
#                price          0.451367
#   milage       model_year    -0.442418
#                price         -0.391919
#   accident     clean_title    0.309393
#   clean_title  accident       0.309393
#   price        model_year     0.451367
#                milage        -0.391919
#   dtype: float64),
#  ('engine name: 560.0HP 4.4L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year   milage        -0.417297
#   milage       model_year    -0.417297
#                price         -0.326028
#   accident     clean_title    0.402779
#   clean_title  accident       0.402779
#   price        milage        -0.326028
#   dtype: float64),
#  ('engine name: 285.0HP 3.6L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year   milage        -0.706316
#                price          0.366262
#   milage       model_year    -0.706316
#                price         -0.391225
#   accident     clean_title    0.362555
#   clean_title  accident       0.362555
#   price        model_year     0.366262
#                milage        -0.391225
#   dtype: float64),
#  ('engine name: 300.0HP 4.4L 8 Cylinder Engine Gasoline Fuel\n',
#   Series([], dtype: float64)),
#  ('engine name: 302.0HP 5.0L 8 Cylinder Engine Gasoline Fuel\n',
#   Series([], dtype: float64)),
#  ('engine name: 3.0L V6 24V GDI DOHC Twin Turbo\n',
#   model_year  milage       -0.504611
#   milage      model_year   -0.504611
#   dtype: float64),
#  ('engine name: 300.0HP 3.6L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.428868
#               price         0.385587
#   milage      model_year   -0.428868
#               price        -0.365547
#   price       model_year    0.385587
#               milage       -0.365547
#   dtype: float64),
#  ('engine name: 490.0HP 6.2L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year   milage        -0.441400
#   milage       model_year    -0.441400
#   accident     clean_title    0.433437
#   clean_title  accident       0.433437
#   dtype: float64),
#  ('engine name: 300.0HP 5.3L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year  price         0.391055
#   price       model_year    0.391055
#   dtype: float64),
#  ('engine name: 200.0HP 2.0L 4 Cylinder Engine Gasoline Fuel\n',
#   Series([], dtype: float64)),
#  ('engine name: 416.0HP 4.0L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.609958
#               price         0.371387
#   milage      model_year   -0.609958
#               price        -0.393037
#   price       model_year    0.371387
#               milage       -0.393037
#   dtype: float64),
#  ('engine name: 179.0HP 2.5L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  price         0.473406
#   milage      price        -0.548412
#   price       model_year    0.473406
#               milage       -0.548412
#   dtype: float64),
#  ('engine name: 302.0HP 3.5L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.408865
#               price         0.306013
#   milage      model_year   -0.408865
#               price        -0.311858
#   price       model_year    0.306013
#               milage       -0.311858
#   dtype: float64),
#  ('engine name: 3.8L V8 32V MPFI DOHC Twin Turbo\n',
#   model_year  accident     -0.426009
#   milage      price        -0.363265
#   accident    model_year   -0.426009
#   price       milage       -0.363265
#   dtype: float64),
#  ('engine name: 3.4L V6 24V PDI DOHC Twin Turbo Hybrid\n',
#   model_year   milage        -0.656329
#                accident      -0.452146
#                clean_title   -0.430576
#                price          0.503607
#   milage       model_year    -0.656329
#                accident       0.382939
#                price         -0.372094
#   accident     model_year    -0.452146
#                milage         0.382939
#                price         -0.384074
#   clean_title  model_year    -0.430576
#                price         -0.425883
#   price        model_year     0.503607
#                milage        -0.372094
#                accident      -0.384074
#                clean_title   -0.425883
#   dtype: float64),
#  ('engine name: 385.0HP 6.2L 8 Cylinder Engine Flex Fuel Capability\n',
#   model_year  milage       -0.463347
#   milage      model_year   -0.463347
#   dtype: float64),
#  ('engine name: 160.0HP 2.4L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  price         0.324526
#   milage      price        -0.512529
#   price       model_year    0.324526
#               milage       -0.512529
#   dtype: float64),
#  ('engine name: 385.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel\n',
#   accident     clean_title    0.591781
#   clean_title  accident       0.591781
#   dtype: float64),
#  ('engine name: 210.0HP 3.3L V6 Cylinder Engine Gasoline Fuel\n',
#   accident     clean_title    0.300466
#   clean_title  accident       0.300466
#   dtype: float64),
#  ('engine name: 385.0HP 5.0L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.370890
#   milage      model_year   -0.370890
#               price        -0.472838
#   price       milage       -0.472838
#   dtype: float64),
#  ('engine name: 270.0HP 4.0L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.605051
#               price         0.445327
#   milage      model_year   -0.605051
#               price        -0.432281
#   price       model_year    0.445327
#               milage       -0.432281
#   dtype: float64),
#  ('engine name: 560.0HP 4.0L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year   milage        -0.467841
#   milage       model_year    -0.467841
#                price         -0.427066
#   accident     clean_title    0.366094
#   clean_title  accident       0.366094
#   price        milage        -0.427066
#   dtype: float64),
#  ('engine name: 210.0HP 4.0L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year  price         0.306473
#   milage      price        -0.373224
#   price       model_year    0.306473
#               milage       -0.373224
#   dtype: float64),
#  ('engine name: 3.5L V6 24V PDI DOHC Twin Turbo\n',
#   model_year  milage       -0.467704
#   milage      model_year   -0.467704
#   dtype: float64),
#  ('engine name: 310.0HP 2.3L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.656436
#               price         0.332974
#   milage      model_year   -0.656436
#               price        -0.313512
#   price       model_year    0.332974
#               milage       -0.313512
#   dtype: float64),
#  ('engine name: 350.0HP 6.7L Straight 6 Cylinder Engine Diesel Fuel\n',
#   model_year  milage       -0.432955
#   milage      model_year   -0.432955
#   dtype: float64),
#  ('engine name: 190.0HP 4.0L Straight 6 Cylinder Engine Gasoline Fuel\n',
#   milage  price    -0.343947
#   price   milage   -0.343947
#   dtype: float64),
#  ('engine name: 350.0HP 2.3L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year   price          0.486705
#   milage       price         -0.453650
#   accident     clean_title    0.352556
#   clean_title  accident       0.352556
#   price        model_year     0.486705
#                milage        -0.453650
#   dtype: float64),
#  ('engine name: 181.0HP 1.6L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.408742
#               price         0.387938
#   milage      model_year   -0.408742
#               price        -0.512984
#   price       model_year    0.387938
#               milage       -0.512984
#   dtype: float64),
#  ('engine name: 2.0L I4 16V PDI DOHC Turbo\n',
#   model_year  price         0.795044
#   milage      price        -0.365341
#   accident    price        -0.354153
#   price       model_year    0.795044
#               milage       -0.365341
#               accident     -0.354153
#   dtype: float64),
#  ('engine name: 300.0HP 4.6L 8 Cylinder Engine Gasoline Fuel\n',
#   Series([], dtype: float64)),
#  ('engine name: 270.0HP 3.5L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.493481
#               price         0.573996
#   milage      model_year   -0.493481
#               price        -0.503585
#   price       model_year    0.573996
#               milage       -0.503585
#   dtype: float64),
#  ('engine name: 265.0HP 3.5L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.502291
#   milage      model_year   -0.502291
#   dtype: float64),
#  ('engine name: 345.0HP 5.7L 8 Cylinder Engine Gasoline Fuel\n',
#   Series([], dtype: float64)),
#  ('engine name: 400.0HP 3.0L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year   milage        -0.614880
#                price          0.376224
#   milage       model_year    -0.614880
#                price         -0.305971
#   accident     clean_title    0.316410
#   clean_title  accident       0.316410
#   price        model_year     0.376224
#                milage        -0.305971
#   dtype: float64),
#  ('engine name: 261.0HP 4.0L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.360456
#               price         0.305478
#   milage      model_year   -0.360456
#               price        -0.376821
#   price       model_year    0.305478
#               milage       -0.376821
#   dtype: float64),
#  ('engine name: 355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.553093
#               price         0.456752
#   milage      model_year   -0.553093
#               price        -0.413935
#   price       model_year    0.456752
#               milage       -0.413935
#   dtype: float64),
#  ('engine name: 536.0HP 5.5L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year   milage        -0.485946
#                price          0.433493
#   milage       model_year    -0.485946
#                accident       0.316180
#                price         -0.422111
#   accident     milage         0.316180
#                clean_title    0.313619
#   clean_title  accident       0.313619
#   price        model_year     0.433493
#                milage        -0.422111
#   dtype: float64),
#  ('engine name: 320.0HP 5.3L 8 Cylinder Engine Gasoline Fuel\n',
#   milage  price    -0.333745
#   price   milage   -0.333745
#   dtype: float64),
# ...
#   dtype: float64),
#  ('engine name: 2.5L I4 16V PDI DOHC Hybrid\n',
#   model_year  milage       -0.895633
#               price         0.582674
#   milage      model_year   -0.895633
#               price        -0.510303
#   price       model_year    0.582674
#               milage       -0.510303
#   dtype: float64),
#  ('engine name: 242.0HP 3.3L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.694512
#               price         0.839792
#   milage      model_year   -0.694512
#               price        -0.667675
#   accident    price        -0.360455
#   price       model_year    0.839792
#               milage       -0.667675
#               accident     -0.360455
#   dtype: float64),
#  ('engine name: 4.4 Liter DOHC Twin Turbo\n',
#   model_year  price         0.322803
#   price       model_year    0.322803
#   dtype: float64),
#  ('engine name: 131.0HP 2.0L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.667888
#               accident     -0.510206
#               price         0.701637
#   milage      model_year   -0.667888
#               price        -0.670357
#   accident    model_year   -0.510206
#               price        -0.372803
#   price       model_year    0.701637
#               milage       -0.670357
#               accident     -0.372803
#   dtype: float64),
#  ('engine name: 6.2L V8 16V GDI OHV Supercharged\n',
#   model_year  milage       -0.467635
#   milage      model_year   -0.467635
#   dtype: float64),
#  ('engine name: 147.0HP Electric Motor Electric Fuel System\n',
#   model_year  milage       -0.826701
#               accident     -0.530455
#               price         0.480778
#   milage      model_year   -0.826701
#               accident      0.352056
#               price        -0.571491
#   accident    model_year   -0.530455
#               milage        0.352056
#               price        -0.415569
#   price       model_year    0.480778
#               milage       -0.571491
#               accident     -0.415569
#   dtype: float64),
#  ('engine name: 138.0HP 2.0L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.566640
#               accident     -0.428571
#               price         0.617066
#   milage      model_year   -0.566640
#               price        -0.566661
#   accident    model_year   -0.428571
#   price       model_year    0.617066
#               milage       -0.566661
#   dtype: float64),
#  ('engine name: 395.0HP 6.0L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.588262
#               price         0.465333
#   milage      model_year   -0.588262
#               accident      0.536706
#               price        -0.470799
#   accident    milage        0.536706
#               price        -0.319178
#   price       model_year    0.465333
#               milage       -0.470799
#               accident     -0.319178
#   dtype: float64),
#  ('engine name: 155.0HP 1.3L 3 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.790402
#   milage      model_year   -0.790402
#   dtype: float64),
#  ('engine name: 186.0HP 2.0L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.559936
#               price         0.514881
#   milage      model_year   -0.559936
#               price        -0.694520
#   price       model_year    0.514881
#               milage       -0.694520
#   dtype: float64),
#  ('engine name: 180.0HP 2.4L 4 Cylinder Engine Flex Fuel Capability\n',
#   model_year   milage        -0.386074
#   milage       model_year    -0.386074
#   accident     clean_title    0.534365
#                price         -0.311419
#   clean_title  accident       0.534365
#   price        accident      -0.311419
#   dtype: float64),
#  ('engine name: 415.0HP 3.6L Flat 6 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.324749
#               price         0.690952
#   milage      model_year   -0.324749
#               price        -0.383098
#   accident    price         0.329687
#   price       model_year    0.690952
#               milage       -0.383098
#               accident      0.329687
#   dtype: float64),
#  ('engine name: 200.0HP 1.6L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year   accident       0.322184
#                clean_title    0.624258
#   milage       price         -0.334409
#   accident     model_year     0.322184
#                clean_title    0.456630
#   clean_title  model_year     0.624258
#                accident       0.456630
#   price        milage        -0.334409
#   dtype: float64),
#  ('engine name: 210.0HP 4.0L Straight 6 Cylinder Engine Gasoline Fuel\n',
#   model_year  accident     -0.426482
#   milage      price        -0.318812
#   accident    model_year   -0.426482
#   price       milage       -0.318812
#   dtype: float64),
#  ('engine name: 552.0HP 6.0L 12 Cylinder Engine Flex Fuel Capability\n',
#   accident     clean_title    0.662541
#                price         -0.686890
#   clean_title  accident       0.662541
#                price         -0.998158
#   price        accident      -0.686890
#                clean_title   -0.998158
#   dtype: float64),
#  ('engine name: 205.0HP 1.5L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.471817
#               price         0.388716
#   milage      model_year   -0.471817
#               price        -0.706011
#   accident    price        -0.525105
#   price       model_year    0.388716
#               milage       -0.706011
#               accident     -0.525105
#   dtype: float64),
#  ('engine name: 319.0HP 6.0L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year  price        -0.428752
#   milage      accident      0.436580
#               price        -0.695948
#   accident    milage        0.436580
#   price       model_year   -0.428752
#               milage       -0.695948
#   dtype: float64),
#  ('engine name: 6.8L V12 48V GDI DOHC\n',
#   model_year   price         -0.589395
#   accident     clean_title    0.372104
#   clean_title  accident       0.372104
#   price        model_year    -0.589395
#   dtype: float64),
#  ('engine name: 400.0HP 3.6L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year   milage        -0.659896
#                accident      -0.465458
#                clean_title   -0.546238
#                price          0.402263
#   milage       model_year    -0.659896
#                accident       0.673265
#                clean_title    0.386577
#                price         -0.463811
#   accident     model_year    -0.465458
#                milage         0.673265
#                clean_title    0.573539
#   clean_title  model_year    -0.546238
#                milage         0.386577
#                accident       0.573539
#   price        model_year     0.402263
#                milage        -0.463811
#   dtype: float64),
#  ('engine name: 393.0HP 6.2L 8 Cylinder Engine Gasoline Fuel\n',
#   milage       price         -0.525678
#   accident     clean_title    0.412510
#   clean_title  accident       0.412510
#   price        milage        -0.525678
#   dtype: float64),
#  ('engine name: 324.0HP 6.0L 8 Cylinder Engine Flex Fuel Capability\n',
#   model_year  milage       -0.318185
#               price         0.594445
#   milage      model_year   -0.318185
#               price        -0.749032
#   price       model_year    0.594445
#               milage       -0.749032
#   dtype: float64),
#  ('engine name: 161.0HP 2.4L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  price         0.388295
#   milage      price        -0.315781
#   price       model_year    0.388295
#               milage       -0.315781
#   dtype: float64),
#  ('engine name: 401.0HP 2.5L 5 Cylinder Engine Gasoline Fuel\n',
#   model_year   milage        -0.784890
#                price          0.379864
#   milage       model_year    -0.784890
#                price         -0.337889
#   accident     clean_title    0.792118
#   clean_title  accident       0.792118
#   price        model_year     0.379864
#                milage        -0.337889
#   dtype: float64),
#  ('engine name: 138.0HP 1.6L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year   milage        -0.308171
#                price          0.487586
#   milage       model_year    -0.308171
#                accident       0.453162
#                price         -0.420561
#   accident     milage         0.453162
#                clean_title    0.455803
#                price         -0.406296
#   clean_title  accident       0.455803
#                price         -0.483417
#   price        model_year     0.487586
#                milage        -0.420561
#                accident      -0.406296
#                clean_title   -0.483417
#   dtype: float64),
#  ('engine name: 357.0HP 1.5L 3 Cylinder Engine Plug-In Electric-Gas\n',
#   model_year  milage       -0.433215
#               accident     -0.390880
#   milage      model_year   -0.433215
#               accident      0.599247
#               price        -0.540283
#   accident    model_year   -0.390880
#               milage        0.599247
#   price       milage       -0.540283
#   dtype: float64),
#  ('engine name: 120.0HP 1.6L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.586192
#               price         0.551850
#   milage      model_year   -0.586192
#               accident      0.482197
#               price        -0.527721
#   accident    milage        0.482197
#   price       model_year    0.551850
#               milage       -0.527721
#   dtype: float64),
#  ('engine name: 556.0HP 6.2L 8 Cylinder Engine Gasoline Fuel\n',
#   Series([], dtype: float64)),
#  ('engine name: Battery Electric\n',
#   model_year  milage       -0.464500
#               price        -0.600118
#   milage      model_year   -0.464500
#   price       model_year   -0.600118
#   dtype: float64),
#  ('engine name: 156.0HP 2.0L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.606197
#               price         0.724784
#   milage      model_year   -0.606197
#               accident      0.534413
#               price        -0.878688
#   accident    milage        0.534413
#               price        -0.498251
#   price       model_year    0.724784
#               milage       -0.878688
#               accident     -0.498251
#   dtype: float64),
#  ('engine name: 275.0HP 2.0L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.454375
#               accident     -0.448740
#               price         0.498456
#   milage      model_year   -0.454375
#               price        -0.710331
#   accident    model_year   -0.448740
#               price        -0.481695
#   price       model_year    0.498456
#               milage       -0.710331
#               accident     -0.481695
#   dtype: float64),
#  ('engine name: 420.0HP 4.7L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.478226
#               price         0.504918
#   milage      model_year   -0.478226
#               price        -0.356773
#   price       model_year    0.504918
#               milage       -0.356773
#   dtype: float64),
#  ('engine name: 215.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel\n',
#   milage    accident    0.315056
#             price      -0.732117
#   accident  milage      0.315056
#   price     milage     -0.732117
#   dtype: float64),
#  ('engine name: 180.0HP 3.4L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.477672
#               accident     -0.350598
#               price         0.698590
#   milage      model_year   -0.477672
#               accident      0.714945
#               price        -0.850476
#   accident    model_year   -0.350598
#               milage        0.714945
#               price        -0.488775
#   price       model_year    0.698590
#               milage       -0.850476
#               accident     -0.488775
#   dtype: float64),
#  ('engine name: 175.0HP 1.6L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.374503
#               price         0.470710
#   milage      model_year   -0.374503
#               price        -0.541159
#   accident    price        -0.587238
#   price       model_year    0.470710
#               milage       -0.541159
#               accident     -0.587238
#   dtype: float64),
#  ('engine name: 518.0HP 6.2L 8 Cylinder Engine Gasoline Fuel\n',
#   model_year   milage        -0.537544
#                accident      -0.345841
#                clean_title   -0.313038
#                price          0.358577
#   milage       model_year    -0.537544
#                price         -0.371315
#   accident     model_year    -0.345841
#                clean_title    0.466193
#   clean_title  model_year    -0.313038
#                accident       0.466193
#   price        model_year     0.358577
#                milage        -0.371315
#   dtype: float64),
#  ('engine name: 170.0HP 2.0L 4 Cylinder Engine Gasoline Fuel\n',
#   milage    accident    0.550181
#             price      -0.680910
#   accident  milage      0.550181
#             price      -0.615980
#   price     milage     -0.680910
#             accident   -0.615980
#   dtype: float64),
#  ('engine name: 260.0HP 3.6L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.579283
#               price         0.630593
#   milage      model_year   -0.579283
#               price        -0.747748
#   price       model_year    0.630593
#               milage       -0.747748
#   dtype: float64),
#  ('engine name: 137.0HP 1.8L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.908499
#               price         0.867787
#   milage      model_year   -0.908499
#               price        -0.858966
#   accident    price        -0.342835
#   price       model_year    0.867787
#               milage       -0.858966
#               accident     -0.342835
#   dtype: float64),
#  ('engine name: 287.0HP 3.6L V6 Cylinder Engine Gasoline Fuel\n',
#   model_year  milage       -0.805256
#               price         0.334542
#   milage      model_year   -0.805256
#               price        -0.441384
#   price       model_year    0.334542
#               milage       -0.441384
#   dtype: float64),
#  ('engine name: 265.0HP 3.0L V6 Cylinder Engine Gasoline Fuel\n',
#   milage       price         -0.54310
#   accident     clean_title    0.57735
#   clean_title  accident       0.57735
#   price        milage        -0.54310
#   dtype: float64),
#  ('engine name: 180.0HP 2.5L 4 Cylinder Engine Gasoline Fuel\n',
#   model_year  price         0.498086
#   milage      price        -0.387561
#   price       model_year    0.498086
#               milage       -0.387561
#   dtype: float64),
#  ...]
# ---------------------
# [('fuel_type name: Gasoline\n',
#   model_year  milage       -0.669522
#   milage      model_year   -0.669522
#               accident      0.306501
#   accident    milage        0.306501
#   dtype: float64),
#  ('fuel_type name: E85 Flex Fuel\n',
#   model_year  milage       -0.564519
#   milage      model_year   -0.564519
#   dtype: float64),
#  ('fuel_type name: -1\n',
#   model_year  milage       -0.625264
#   milage      model_year   -0.625264
#   dtype: float64),
#  ('fuel_type name: Hybrid\n',
#   model_year  milage       -0.749230
#               accident     -0.425604
#               price         0.307806
#   milage      model_year   -0.749230
#               accident      0.404063
#               price        -0.325571
#   accident    model_year   -0.425604
#               milage        0.404063
#   price       model_year    0.307806
#               milage       -0.325571
#   dtype: float64),
#  ('fuel_type name: Diesel\n',
#   model_year   milage        -0.649369
#   milage       model_year    -0.649369
#   accident     clean_title    0.314911
#   clean_title  accident       0.314911
#   dtype: float64),
#  ('fuel_type name: Plug-In Hybrid\n',
#   model_year  milage       -0.671492
#               price         0.455706
#   milage      model_year   -0.671492
#               accident      0.319701
#               price        -0.421026
#   accident    milage        0.319701
#   price       model_year    0.455706
#               milage       -0.421026
#   dtype: float64),
#  ('fuel_type name: –\n',
#   model_year   milage        -0.333094
#   milage       model_year    -0.333094
#   accident     clean_title    0.356017
#   clean_title  accident       0.356017
#   dtype: float64),
#  ('fuel_type name: not supported\n',
#   model_year  milage       -0.696937
#               price         0.591466
#   milage      model_year   -0.696937
#               price        -0.697098
#   price       model_year    0.591466
#               milage       -0.697098
#   dtype: float64)]

# %%
def corr_comuni(filtered_corr_list,nome_lista):

    correlation_dict = {}

    for group_info, filtered_corr in filtered_corr_list:
        group_name = group_info.strip()  # Estrai nome del brand
        for (col1, col2), value in filtered_corr.items():
            pair = tuple(sorted([col1, col2]))
            correlation_dict.setdefault(pair, set()).add(group_name)

    #Filtra le coppie presenti in almeno 2 brand
    relevant_correlations = {pair: names for pair, names in correlation_dict.items() if len(names) >= 2}

    #Stampa i risultati
    print(f"Correlazioni presenti in 2 o più {nome_lista}:")
    for pair, names in relevant_correlations.items():
        print(f"{pair}: presenti in {len(names)} {nome_lista} -> {', '.join(names)}")

    return relevant_correlations


relevant_correlations_brands = corr_comuni(filtered_corr_brands,"brands")
print("\n\n---------------------\n\n")
relevant_correlations_engines = corr_comuni(filtered_corr_engines, "engines")
print("\n\n---------------------\n\n")
relevant_correlations_fuels = corr_comuni(filtered_corr_fuels, "fuels")
print("\n\n---------------------\n\n")
relevant_correlations_trans = corr_comuni(filtered_corr_trans, "transmissions")
print("\n\n---------------------\n\n")
# Out:
# Correlazioni presenti in 2 o più brands:
# ('milage', 'model_year'): presenti in 49 brands -> brand name: Audi, brand name: Bentley, brand name: Aston, brand name: Land, brand name: Saturn, brand name: Saab, brand name: MINI, brand name: Nissan, brand name: Hyundai, brand name: Lamborghini, brand name: Volvo, brand name: Lotus, brand name: FIAT, brand name: Cadillac, brand name: smart, brand name: Acura, brand name: BMW, brand name: Rivian, brand name: Porsche, brand name: Subaru, brand name: Jaguar, brand name: Tesla, brand name: Mazda, brand name: Kia, brand name: Alfa, brand name: Toyota, brand name: Lincoln, brand name: GMC, brand name: INFINITI, brand name: Maserati, brand name: Rolls-Royce, brand name: Ferrari, brand name: RAM, brand name: Karma, brand name: Lucid, brand name: Polestar, brand name: Chrysler, brand name: Buick, brand name: Chevrolet, brand name: Mercedes-Benz, brand name: Scion, brand name: Lexus, brand name: Genesis, brand name: Volkswagen, brand name: Jeep, brand name: Honda, brand name: Mitsubishi, brand name: Dodge, brand name: Ford
# ('model_year', 'price'): presenti in 25 brands -> brand name: Saturn, brand name: Saab, brand name: MINI, brand name: Maybach, brand name: Nissan, brand name: Volvo, brand name: Lotus, brand name: FIAT, brand name: smart, brand name: Acura, brand name: BMW, brand name: Subaru, brand name: Kia, brand name: Alfa, brand name: Lincoln, brand name: Maserati, brand name: Karma, brand name: Lucid, brand name: Polestar, brand name: Hummer, brand name: Buick, brand name: Scion, brand name: Volkswagen, brand name: Jeep, brand name: Bugatti
# ('milage', 'price'): presenti in 26 brands -> brand name: Audi, brand name: Saturn, brand name: Saab, brand name: MINI, brand name: Maybach, brand name: Nissan, brand name: Volvo, brand name: Lotus, brand name: FIAT, brand name: smart, brand name: Acura, brand name: BMW, brand name: Subaru, brand name: Kia, brand name: Alfa, brand name: Lincoln, brand name: Maserati, brand name: Plymouth, brand name: Karma, brand name: Polestar, brand name: Hummer, brand name: Buick, brand name: Scion, brand name: Volkswagen, brand name: Jeep, brand name: Dodge
# ('accident', 'milage'): presenti in 13 brands -> brand name: Kia, brand name: smart, brand name: Land, brand name: Chevrolet, brand name: Acura, brand name: Plymouth, brand name: Lexus, brand name: Maybach, brand name: Jeep, brand name: Karma, brand name: Suzuki, brand name: Dodge, brand name: Lotus
# ('clean_title', 'model_year'): presenti in 17 brands -> brand name: Kia, brand name: Audi, brand name: smart, brand name: Polestar, brand name: Toyota, brand name: Buick, brand name: Acura, brand name: Mercedes-Benz, brand name: Lexus, brand name: Honda, brand name: Jeep, brand name: Nissan, brand name: Karma, brand name: Hyundai, brand name: Lamborghini, brand name: Suzuki, brand name: Bugatti
# ('clean_title', 'milage'): presenti in 12 brands -> brand name: Kia, brand name: Audi, brand name: smart, brand name: Polestar, brand name: Buick, brand name: Acura, brand name: Lexus, brand name: Honda, brand name: Jeep, brand name: Karma, brand name: Hyundai, brand name: Bugatti
# ('accident', 'clean_title'): presenti in 9 brands -> brand name: FIAT, brand name: Bentley, brand name: smart, brand name: Polestar, brand name: Rivian, brand name: Mercury, brand name: Lucid, brand name: Suzuki, brand name: Lotus
# ('accident', 'model_year'): presenti in 8 brands -> brand name: Kia, brand name: smart, brand name: Maserati, brand name: Lexus, brand name: Jeep, brand name: Karma, brand name: Dodge, brand name: Lotus
# ('accident', 'price'): presenti in 5 brands -> brand name: smart, brand name: Maybach, brand name: Saab, brand name: Karma, brand name: Suzuki
# ('clean_title', 'price'): presenti in 4 brands -> brand name: Suzuki, brand name: smart, brand name: Polestar, brand name: Karma
#
#
# ---------------------
#
#
# Correlazioni presenti in 2 o più engines:
# ('milage', 'price'): presenti in 720 engines -> engine name: 306.0HP 3.8L V6 Cylinder Engine Gasoline Fuel, engine name: 353.0HP 6.0L 8 Cylinder Engine Gasoline Fuel, engine name: 316.0HP 6.2L 8 Cylinder Engine Flex Fuel Capability, engine name: 305.0HP 6.8L 10 Cylinder Engine Gasoline Fuel, engine name: 3.8L V6 24V MPFI DOHC Twin Turbo, engine name: 271.0HP Electric Motor Electric Fuel System, engine name: 306.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel, engine name: 115.0HP Electric Motor Electric Fuel System, engine name: 266.0HP Electric Motor Electric Fuel System, engine name: 260.0HP 2.4L 4 Cylinder Engine Gasoline Fuel, engine name: 138.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 2.0L I4 16V GDI DOHC Flexible Fuel, engine name: 111.2Ah - FR 70kW - RR 160kW (697V), engine name: 557.0HP 5.0L 8 Cylinder Engine Gasoline Fuel, engine name: 227.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 403.0HP 6.2L 8 Cylinder Engine Gasoline Fuel, engine name: 330.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 250.0HP 2.7L V6 Cylinder Engine Gasoline Fuel, engine name: 240.0HP 3.0L V6 Cylinder Engine Diesel Fuel, engine name: 232.0HP 1.3L Rotary engine Gasoline Fuel, engine name: 295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 265.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 645.0HP 8.4L 10 Cylinder Engine Gasoline Fuel, engine name: 174.0HP 2.8L V6 Cylinder Engine Gasoline Fuel, engine name: 360.0HP 5.7L 8 Cylinder Engine Gasoline Fuel, engine name: 1.5 Liter Turbo, engine name: 440.0HP 4.8L 8 Cylinder Engine Gasoline Fuel, engine name: 252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 370.0HP 5.7L 8 Cylinder Engine Gasoline Fuel, engine name: 357.0HP 1.5L 3 Cylinder Engine Plug-In Electric-Gas, engine name: 168.0HP 2.4L 4 Cylinder Engine Gasoline Fuel, engine name: 258.0HP 3.2L V6 Cylinder Engine Gasoline Fuel, engine name: 106.0HP 1.5L 4 Cylinder Engine Gasoline Fuel, engine name: 375.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel, engine name: 518.0HP Electric Motor Electric Fuel System, engine name: 295.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 101.0HP 1.4L 4 Cylinder Engine Gasoline Fuel, engine name: 552.0HP 6.0L 12 Cylinder Engine Gasoline Fuel, engine name: 155.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 76.0HP 1.5L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 164.0HP 1.4L 4 Cylinder Engine Gasoline Fuel, engine name: 281.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 180.0HP 6.5L 8 Cylinder Engine Diesel Fuel, engine name: 382.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 311.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 266.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 450.0HP 4.2L 8 Cylinder Engine Gasoline Fuel, engine name: 2.5L I4 16V GDI DOHC Turbo, engine name: 292.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 160.0HP 1.4L 4 Cylinder Engine Gasoline Fuel, engine name: 310.0HP 5.4L 8 Cylinder Engine Flex Fuel Capability, engine name: 120 AH, engine name: 380.0HP 4.3L 8 Cylinder Engine Gasoline Fuel, engine name: 134.0HP 1.5L 3 Cylinder Engine Gasoline Fuel, engine name: 263.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 380.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel, engine name: 310.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 210.0HP 4.0L V6 Cylinder Engine Gasoline Fuel, engine name: 400.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 2.4L I4 16V MPFI DOHC, engine name: 154.0HP 2.7L 5 Cylinder Engine Diesel Fuel, engine name: 420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel, engine name: 560.0HP 4.0L 8 Cylinder Engine Gasoline Fuel, engine name: 302.0HP 4.6L 8 Cylinder Engine Gasoline Fuel, engine name: 145.0HP 1.8L 4 Cylinder Engine Gasoline Fuel, engine name: 220.0HP 2.0L 4 Cylinder Engine Flex Fuel Capability, engine name: 188.0HP 1.6L 4 Cyl ...
# ('milage', 'model_year'): presenti in 761 engines -> engine name: 302.0HP 2.5L 4 Cylinder Engine Plug-In Electric-Gas, engine name: 6.2L V8 16V GDI OHV Supercharged, engine name: 316.0HP 6.2L 8 Cylinder Engine Flex Fuel Capability, engine name: 305.0HP 6.8L 10 Cylinder Engine Gasoline Fuel, engine name: 3.8L V6 24V MPFI DOHC Twin Turbo, engine name: 4.4 Liter, engine name: 271.0HP Electric Motor Electric Fuel System, engine name: 3.0L, engine name: 266.0HP Electric Motor Electric Fuel System, engine name: 260.0HP 2.4L 4 Cylinder Engine Gasoline Fuel, engine name: 3.6L V6 GDI DOHC, engine name: 138.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 111.2Ah - FR 70kW - RR 160kW (697V), engine name: 557.0HP 5.0L 8 Cylinder Engine Gasoline Fuel, engine name: 227.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 443.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel, engine name: 3.5L V6 24V PDI DOHC Twin Turbo Hybrid, engine name: 240.0HP 3.0L V6 Cylinder Engine Diesel Fuel, engine name: 295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 265.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 360.0HP 5.7L 8 Cylinder Engine Gasoline Fuel, engine name: 1.5 Liter Turbo, engine name: 252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 362.0HP 5.4L 8 Cylinder Engine Gasoline Fuel, engine name: 370.0HP 5.7L 8 Cylinder Engine Gasoline Fuel, engine name: 6.6 Liter Twin Turbo, engine name: 357.0HP 1.5L 3 Cylinder Engine Plug-In Electric-Gas, engine name: 258.0HP 3.2L V6 Cylinder Engine Gasoline Fuel, engine name: 315.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 106.0HP 1.5L 4 Cylinder Engine Gasoline Fuel, engine name: 375.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 523.0HP 4.4L 8 Cylinder Engine Gasoline Fuel, engine name: 333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel, engine name: 518.0HP Electric Motor Electric Fuel System, engine name: 295.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 101.0HP 1.4L 4 Cylinder Engine Gasoline Fuel, engine name: 437.0HP 3.4L V6 Cylinder Engine Gas-Electric Hybrid, engine name: 155.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 76.0HP 1.5L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 164.0HP 1.4L 4 Cylinder Engine Gasoline Fuel, engine name: 281.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 311.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 3.6 Liter, engine name: 266.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 2.5L I4 16V GDI DOHC Turbo, engine name: 292.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 288.0HP 2.0L 4 Cylinder Engine Plug-In Electric-Gas, engine name: 310.0HP 5.4L 8 Cylinder Engine Flex Fuel Capability, engine name: 120 AH, engine name: 134.0HP 1.5L 3 Cylinder Engine Gasoline Fuel, engine name: 263.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 1.5L I3 12V PDI DOHC Turbo, engine name: 380.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 310.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 3.5L V6 24V GDI SOHC, engine name: 400.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 2.4L I4 16V MPFI DOHC, engine name: 420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel, engine name: 560.0HP 4.0L 8 Cylinder Engine Gasoline Fuel, engine name: 375.0HP 5.6L 8 Cylinder Engine Gasoline Fuel, engine name: 145.0HP 1.8L 4 Cylinder Engine Gasoline Fuel, engine name: 220.0HP 2.0L 4 Cylinder Engine Flex Fuel Capability, engine name: 395.0HP 3.0L Straight 6 Cylinder Engine Gasoline-Mild Electric Hybrid, engine name: 265.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 294.0HP 4.2L 8 Cylinder Engine Gasoline Fuel, engine name: 4.7L 8 Cylinder Engine Gasoline Fuel, engine name: 6.2L V8 16V GDI OHV, engine name: 250.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 277.0HP 3.0L Straight 6 Cylinder Engine Diesel Fuel, engine name: 2.4L I4 16V PDI DOHC Turbo, engine name: 2.0 Liter TFSI, engine name: 2.0L I4 16V GDI DOHC Turbo, engine name: 621.0HP 6.0L 12 Cylinder Engine Ga ...
# ('model_year', 'price'): presenti in 571 engines -> engine name: 306.0HP 3.8L V6 Cylinder Engine Gasoline Fuel, engine name: 302.0HP 2.5L 4 Cylinder Engine Plug-In Electric-Gas, engine name: 316.0HP 6.2L 8 Cylinder Engine Flex Fuel Capability, engine name: 305.0HP 6.8L 10 Cylinder Engine Gasoline Fuel, engine name: 271.0HP Electric Motor Electric Fuel System, engine name: 567.0HP 6.0L 12 Cylinder Engine Flex Fuel Capability, engine name: 115.0HP Electric Motor Electric Fuel System, engine name: 266.0HP Electric Motor Electric Fuel System, engine name: 260.0HP 2.4L 4 Cylinder Engine Gasoline Fuel, engine name: 138.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 2.0L I4 16V GDI DOHC Flexible Fuel, engine name: 111.2Ah - FR 70kW - RR 160kW (697V), engine name: 557.0HP 5.0L 8 Cylinder Engine Gasoline Fuel, engine name: 227.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 250.0HP 2.7L V6 Cylinder Engine Gasoline Fuel, engine name: 330.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 240.0HP 3.0L V6 Cylinder Engine Diesel Fuel, engine name: 232.0HP 1.3L Rotary engine Gasoline Fuel, engine name: 295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 174.0HP 2.8L V6 Cylinder Engine Gasoline Fuel, engine name: 360.0HP 5.7L 8 Cylinder Engine Gasoline Fuel, engine name: 252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 370.0HP 5.7L 8 Cylinder Engine Gasoline Fuel, engine name: 6.6 Liter Twin Turbo, engine name: 3.2L V6 18V MPFI SOHC, engine name: 375.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 333.0HP 3.0L V6 Cylinder Engine Gasoline Fuel, engine name: 101.0HP 1.4L 4 Cylinder Engine Gasoline Fuel, engine name: 155.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 4.4 Liter DOHC Twin Turbo, engine name: 76.0HP 1.5L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 281.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 164.0HP 1.4L 4 Cylinder Engine Gasoline Fuel, engine name: 180.0HP 6.5L 8 Cylinder Engine Diesel Fuel, engine name: 311.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 266.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 2.5L I4 16V GDI DOHC Turbo, engine name: 292.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 120 AH, engine name: 134.0HP 1.5L 3 Cylinder Engine Gasoline Fuel, engine name: 263.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 310.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 210.0HP 4.0L V6 Cylinder Engine Gasoline Fuel, engine name: 400.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 2.4L I4 16V MPFI DOHC, engine name: 154.0HP 2.7L 5 Cylinder Engine Diesel Fuel, engine name: 420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel, engine name: 270.0HP 4.8L 8 Cylinder Engine Gasoline Fuel, engine name: 145.0HP 1.8L 4 Cylinder Engine Gasoline Fuel, engine name: 220.0HP 2.0L 4 Cylinder Engine Flex Fuel Capability, engine name: 188.0HP 1.6L 4 Cylinder Engine Gasoline Fuel, engine name: 290.0HP Electric Motor Electric Fuel System, engine name: 294.0HP 4.2L 8 Cylinder Engine Gasoline Fuel, engine name: 4.7L 8 Cylinder Engine Gasoline Fuel, engine name: 252.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 250.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 175.0HP 1.6L 4 Cylinder Engine Gasoline Fuel, engine name: 203.0HP 2.5L 4 Cylinder Engine Gasoline Fuel, engine name: 186.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 295.0HP 5.3L 8 Cylinder Engine Flex Fuel Capability, engine name: 199.0HP 2.4L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 4.0L, engine name: 650.0HP 5.8L 8 Cylinder Engine Gasoline Fuel, engine name: 365.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 122.0HP 1.8L 4 Cylinder Engine Gasoline Fuel, engine name: 323.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 219.0HP 2.5L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 407.0HP 4.4L 8 Cylinder Engine Gasoline Fuel, engine name: 317.0HP 5.6L 8 Cylinder Engine Flex Fuel Capability, engine name: 131.0HP 2.0 ...
# ('accident', 'clean_title'): presenti in 308 engines -> engine name: 271.0HP Electric Motor Electric Fuel System, engine name: 557.0HP 5.0L 8 Cylinder Engine Gasoline Fuel, engine name: 443.0HP 3.0L Flat 6 Cylinder Engine Gasoline Fuel, engine name: 403.0HP 6.2L 8 Cylinder Engine Gasoline Fuel, engine name: 168.0HP 2.4L 4 Cylinder Engine Gasoline Fuel, engine name: 523.0HP 4.4L 8 Cylinder Engine Gasoline Fuel, engine name: 295.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 437.0HP 3.4L V6 Cylinder Engine Gas-Electric Hybrid, engine name: 552.0HP 6.0L 12 Cylinder Engine Gasoline Fuel, engine name: 155.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 266.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 160.0HP 1.4L 4 Cylinder Engine Gasoline Fuel, engine name: 400.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel, engine name: 560.0HP 4.0L 8 Cylinder Engine Gasoline Fuel, engine name: 302.0HP 4.6L 8 Cylinder Engine Gasoline Fuel, engine name: 480.0HP 3.6L Flat 6 Cylinder Engine Gasoline Fuel, engine name: 395.0HP 3.0L Straight 6 Cylinder Engine Gasoline-Mild Electric Hybrid, engine name: 240.0HP 4.7L 8 Cylinder Engine Gasoline Fuel, engine name: 4.7L 8 Cylinder Engine Gasoline Fuel, engine name: 277.0HP 3.0L Straight 6 Cylinder Engine Diesel Fuel, engine name: 533.0HP Electric Motor Electric Fuel System, engine name: 621.0HP 6.0L 12 Cylinder Engine Gasoline Fuel, engine name: 203.0HP 2.5L 4 Cylinder Engine Gasoline Fuel, engine name: 380.0HP 4.6L 8 Cylinder Engine Gasoline Fuel, engine name: 320.0HP Electric Motor Electric Fuel System, engine name: 400.0HP 6.7L 8 Cylinder Engine Diesel Fuel, engine name: 502.0HP 4.0L Flat 6 Cylinder Engine Gasoline Fuel, engine name: 290.0HP 4.0L 8 Cylinder Engine Gasoline Fuel, engine name: 382.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel, engine name: 591.0HP 4.0L 8 Cylinder Engine Gasoline Fuel, engine name: 180.0HP 1.6L 4 Cylinder Engine Plug-In Electric-Gas, engine name: 565.0HP 3.8L V6 Cylinder Engine Gasoline Fuel, engine name: 425.0HP Electric Motor Electric Fuel System, engine name: 6.7L V8 32V DDI OHV Turbo Diesel, engine name: 335.0HP 4.7L 8 Cylinder Engine Gasoline Fuel, engine name: 173.0HP 2.4L 4 Cylinder Engine Gasoline Fuel, engine name: 283.0HP 3.6L V6 Cylinder Engine Flex Fuel Capability, engine name: 390.0HP 6.0L 8 Cylinder Engine Gasoline Fuel, engine name: 475.0HP 6.4L 8 Cylinder Engine Gasoline Fuel, engine name: 107.0HP Electric Motor Electric Fuel System, engine name: 2.5L, engine name: 400.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 450.0HP 4.0L 8 Cylinder Engine Gasoline Fuel, engine name: 275.0HP 3.7L V6 Cylinder Engine Gasoline Fuel, engine name: 354.0HP 3.5L V6 Cylinder Engine Gas-Electric Hybrid, engine name: 265.0HP 3.0L V6 Cylinder Engine Gasoline Fuel, engine name: 536.0HP Electric Motor Electric Fuel System, engine name: 181.0HP 4.0L Straight 6 Cylinder Engine Gasoline Fuel, engine name: 1.6L I4 16V MPFI DOHC, engine name: 291.0HP 3.8L V6 Cylinder Engine Gasoline Fuel, engine name: 181.0HP 1.5L 3 Cylinder Engine Gasoline Fuel, engine name: 389.0HP 3.0L Straight 6 Cylinder Engine Plug-In Electric-Gas, engine name: –, engine name: 518.0HP 5.0L 8 Cylinder Engine Gasoline Fuel, engine name: 381.0HP 5.7L 8 Cylinder Engine Flex Fuel Capability, engine name: 275.0HP 2.3L 4 Cylinder Engine Gasoline Fuel, engine name: 210.0HP 3.3L V6 Cylinder Engine Gasoline Fuel, engine name: 591.0HP 4.0L 8 Cylinder Engine Gasoline-Mild Electric Hybrid, engine name: 182.0HP 2.4L 4 Cylinder Engine Gasoline Fuel, engine name: 575.0HP 5.0L 8 Cylinder Engine Gasoline Fuel, engine name: 449.0HP 4.7L 8 Cylinder Engine Gasoline Fuel, engine name: 389.0HP 3.4L V6 Cylinder Engine Gasoline Fuel, engine name: 201.0HP 2.5L Flat 6 Cylinder Engine Gasoline Fuel, engine name: 180.0HP 1.8L 4 Cylinder Engine Gasoline Fuel, engine name: 536.0HP 5.5L 8 Cylinder Engine Gasoline Fuel, engine name: 456.0HP 4.0L 8 Cylind ...
# ('accident', 'milage'): presenti in 213 engines -> engine name: 319.0HP 6.0L 8 Cylinder Engine Gasoline Fuel, engine name: 286.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 139.0HP 1.6L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 301.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 316.0HP 6.2L 8 Cylinder Engine Flex Fuel Capability, engine name: 536.0HP 5.5L 8 Cylinder Engine Gasoline Fuel, engine name: 3.8L V6 24V MPFI DOHC Twin Turbo, engine name: 355.0HP 6.0L 8 Cylinder Engine Gasoline Fuel, engine name: 335.0HP 6.6L 8 Cylinder Engine Diesel Fuel, engine name: 409.0HP 3.4L V6 Cylinder Engine Gasoline Fuel, engine name: 245.0HP 5.9L 8 Cylinder Engine Gasoline Fuel, engine name: 261.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 215.0HP 3.8L V6 Cylinder Engine Gasoline Fuel, engine name: 115.0HP Electric Motor Electric Fuel System, engine name: 420.0HP 4.8L 8 Cylinder Engine Gasoline Fuel, engine name: 2.4L H4 16V GDI DOHC Turbo, engine name: 375.0HP Electric Motor Electric Fuel System, engine name: 370.0HP 6.7L Straight 6 Cylinder Engine Diesel Fuel, engine name: 271.0HP 2.4L 4 Cylinder Engine Gasoline Fuel, engine name: 197.0HP 3.8L V6 Cylinder Engine Gasoline Fuel, engine name: 2.0L I4 16V GDI DOHC Flexible Fuel, engine name: 3.5L V6 24V GDI DOHC Twin Turbo, engine name: 557.0HP 5.0L 8 Cylinder Engine Gasoline Fuel, engine name: 450.0HP 4.5L 8 Cylinder Engine Gasoline Fuel, engine name: 109.0HP 1.6L 4 Cylinder Engine Gasoline Fuel, engine name: 5.4 Liter, engine name: 605.0HP 5.7L 10 Cylinder Engine Gasoline Fuel, engine name: 305.0HP 5.7L 8 Cylinder Engine Gasoline Fuel, engine name: 2.5L I4 16V MPFI DOHC Hybrid, engine name: 8.0L W16 64V GDI DOHC Twin Turbo, engine name: 335.0HP 5.7L 8 Cylinder Engine Gasoline Fuel, engine name: 429.0HP 3.0L Straight 6 Cylinder Engine Gasoline-Mild Electric Hybrid, engine name: 5.4 Liter SC DOHC, engine name: 455.0HP 2.0L 4 Cylinder Engine Plug-In Electric-Gas, engine name: 645.0HP 8.4L 10 Cylinder Engine Gasoline Fuel, engine name: 3.5L V6 24V GDI DOHC, engine name: 276.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 340.0HP 3.0L V6 Cylinder Engine Flex Fuel Capability, engine name: 400.0HP 5.0L 8 Cylinder Engine Gasoline Fuel, engine name: 1.6L I4 16V GDI DOHC Turbo Hybrid, engine name: 153.0HP 1.4L 4 Cylinder Engine Gasoline Fuel, engine name: 260.0HP 3.0L V6 Cylinder Engine Diesel Fuel, engine name: 357.0HP 1.5L 3 Cylinder Engine Plug-In Electric-Gas, engine name: 228.0HP 2.4L 4 Cylinder Engine Gasoline Fuel, engine name: 258.0HP 3.2L V6 Cylinder Engine Gasoline Fuel, engine name: 176.0HP 2.5L 4 Cylinder Engine Gasoline Fuel, engine name: 405.0HP 4.8L 8 Cylinder Engine Gasoline Fuel, engine name: 150.0HP 2.7L 4 Cylinder Engine Gasoline Fuel, engine name: 275.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 146.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 295.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 255.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 525.0HP 5.2L 10 Cylinder Engine Gasoline Fuel, engine name: 76.0HP 1.5L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 325.0HP 2.0L 4 Cylinder Engine Gasoline-Mild Electric Hybrid, engine name: 164.0HP 1.4L 4 Cylinder Engine Gasoline Fuel, engine name: 362.0HP 3.0L Straight 6 Cylinder Engine Gasoline-Mild Electric Hybrid, engine name: 180.0HP 6.5L 8 Cylinder Engine Diesel Fuel, engine name: 3.2L V6 24V MPFI DOHC, engine name: 521.0HP 4.0L 8 Cylinder Engine Gasoline Fuel, engine name: 365.0HP 2.5L 4 Cylinder Engine Gasoline Fuel, engine name: 382.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 266.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 197.0HP 1.6L 4 Cylinder Engine Gasoline Fuel, engine name: 340.0HP 3.4L Flat 6 Cylinder Engine Gasoline Fuel, engine name: 115.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 288.0HP 2.0L 4 Cylinder Engine Plug-In Electric-Gas, engine name: 208.0HP 2.0L 4 Cylinder Engine Flex Fuel Capability,  ...
# ('accident', 'model_year'): presenti in 146 engines -> engine name: 139.0HP 1.6L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 316.0HP 6.2L 8 Cylinder Engine Flex Fuel Capability, engine name: 602.0HP 5.2L 10 Cylinder Engine Gasoline Fuel, engine name: 335.0HP 6.6L 8 Cylinder Engine Diesel Fuel, engine name: 409.0HP 3.4L V6 Cylinder Engine Gasoline Fuel, engine name: 212.0HP 1.3L Rotary engine Gasoline Fuel, engine name: 261.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 120.0HP 2.2L 4 Cylinder Engine Flex Fuel Capability, engine name: 115.0HP Electric Motor Electric Fuel System, engine name: 375.0HP Electric Motor Electric Fuel System, engine name: 201.0HP 2.0L 4 Cylinder Engine Gasoline-Mild Electric Hybrid, engine name: 3.0L, engine name: 370.0HP 6.7L Straight 6 Cylinder Engine Diesel Fuel, engine name: 3.6L V6 GDI DOHC, engine name: 138.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 285.0HP 3.6L V6 Cylinder Engine Gasoline-Mild Electric Hybrid, engine name: 450.0HP 4.5L 8 Cylinder Engine Gasoline Fuel, engine name: 363.0HP 5.7L 8 Cylinder Engine Gasoline Fuel, engine name: 305.0HP 5.7L 8 Cylinder Engine Gasoline Fuel, engine name: 326.0HP 5.4L 12 Cylinder Engine Gasoline Fuel, engine name: 420.0HP 5.9L 12 Cylinder Engine Gasoline Fuel, engine name: 276.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 212.0HP 1.5L 4 Cylinder Engine Plug-In Electric-Gas, engine name: 212.0HP 2.0L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 357.0HP 1.5L 3 Cylinder Engine Plug-In Electric-Gas, engine name: 228.0HP 2.4L 4 Cylinder Engine Gasoline Fuel, engine name: 5.3L V8 16V MPFI OHV Flexible Fuel, engine name: 3.2L V6 18V MPFI SOHC, engine name: 176.0HP 2.5L 4 Cylinder Engine Gasoline Fuel, engine name: 106.0HP 1.5L 4 Cylinder Engine Gasoline Fuel, engine name: 191.0HP 2.5L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 360.0HP 3.5L V6 Cylinder Engine Gas-Electric Hybrid, engine name: 5.3 Liter, engine name: 395.0HP 5.7L 8 Cylinder Engine Gasoline Fuel, engine name: 275.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 624.0HP 6.6L 12 Cylinder Engine Gasoline Fuel, engine name: 212.0HP 4.5L Straight 6 Cylinder Engine Gasoline Fuel, engine name: 400.0HP 4.2L 8 Cylinder Engine Gasoline Fuel, engine name: 76.0HP 1.5L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 325.0HP 2.0L 4 Cylinder Engine Gasoline-Mild Electric Hybrid, engine name: 164.0HP 1.4L 4 Cylinder Engine Gasoline Fuel, engine name: 362.0HP 3.0L Straight 6 Cylinder Engine Gasoline-Mild Electric Hybrid, engine name: 3.0L V6 24V GDI DOHC Supercharged, engine name: 3.2L V6 24V MPFI DOHC, engine name: 521.0HP 4.0L 8 Cylinder Engine Gasoline Fuel, engine name: 355.0HP 3.0L Straight 6 Cylinder Engine Gasoline-Mild Electric Hybrid, engine name: 197.0HP 1.6L 4 Cylinder Engine Gasoline Fuel, engine name: 208.0HP 2.5L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 322.0HP 2.0L 4 Cylinder Engine Plug-In Electric-Gas, engine name: 253.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 400.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 375.0HP 2.0L 4 Cylinder Engine Plug-In Electric-Gas, engine name: 154.0HP 2.7L 5 Cylinder Engine Diesel Fuel, engine name: 3.8L V8 32V MPFI DOHC Twin Turbo, engine name: 270.0HP 4.8L 8 Cylinder Engine Gasoline Fuel, engine name: 260.0HP 5.4L 8 Cylinder Engine Gasoline Fuel, engine name: 553.0HP 3.9L 8 Cylinder Engine Gasoline Fuel, engine name: 279.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 294.0HP 4.2L 8 Cylinder Engine Gasoline Fuel, engine name: 2.5 Liter, engine name: 4.7L 8 Cylinder Engine Gasoline Fuel, engine name: 151.0HP Electric Motor Hydrogen Fuel, engine name: 533.0HP Electric Motor Electric Fuel System, engine name: 480.0HP 3.8L V6 Cylinder Engine Gasoline Fuel, engine name: 3.5 Liter GTDI, engine name: 4.0L, engine name: 650.0HP 5.8L 8 Cylinder Engine Gasoline Fuel, engine name: 285.0HP 5.7L 8 Cylinder Engine Gasoline Fuel, engine name: 518.0HP 6.2L 8 Cylinder Engine ...
# ('clean_title', 'model_year'): presenti in 51 engines -> engine name: 525.0HP 5.2L 10 Cylinder Engine Gasoline Fuel, engine name: 6.2L V8 32V MPFI DOHC, engine name: 1.6L I4 16V GDI DOHC Hybrid, engine name: 139.0HP 1.6L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 602.0HP 5.2L 10 Cylinder Engine Gasoline Fuel, engine name: 3.8L V6 24V MPFI DOHC Twin Turbo, engine name: 518.0HP 6.2L 8 Cylinder Engine Gasoline Fuel, engine name: 6.8L V12 48V GDI DOHC Twin Turbo, engine name: 115.0HP Electric Motor Electric Fuel System, engine name: 271.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 330.0HP 3.4L Flat 6 Cylinder Engine Gasoline Fuel, engine name: 3.6L V6 GDI DOHC, engine name: 153.0HP 2.3L 4 Cylinder Engine Gasoline Fuel, engine name: 120 AH, engine name: 2.0L I4 16V GDI DOHC Flexible Fuel, engine name: 200.0HP 1.6L 4 Cylinder Engine Gasoline Fuel, engine name: 3.6 Liter DOHC, engine name: 325.0HP 3.4L Flat 6 Cylinder Engine Gasoline Fuel, engine name: 3.4L H6 24V MPFI DOHC, engine name: 5.5 Liter, engine name: 3.2L H6 24V MPFI DOHC, engine name: 320.0HP 3.6L Flat 6 Cylinder Engine Gasoline Fuel, engine name: 467.0HP 5.0L 8 Cylinder Engine Gasoline Fuel, engine name: 247.0HP 2.0L 4 Cylinder Engine Gasoline-Mild Electric Hybrid, engine name: 3.8L V6 12V MPFI OHV, engine name: 147.0HP 1.4L 4 Cylinder Engine Gasoline Fuel, engine name: 132.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 1.5L I3 12V GDI DOHC Turbo, engine name: 400.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 5.4 Liter SC DOHC, engine name: 4.0 Liter Turbo, engine name: 6.0L V8 16V MPFI OHV, engine name: 295.0HP Electric Motor Electric Fuel System, engine name: 385.0HP 6.7L Straight 6 Cylinder Engine Diesel Fuel, engine name: 3.5L V6 24V GDI DOHC, engine name: 2.7L I4 16V GDI DOHC Turbo, engine name: 440.0HP 4.8L 8 Cylinder Engine Gasoline Fuel, engine name: 3.4L V6 24V PDI DOHC Twin Turbo Hybrid, engine name: Dual AC Electric Motors, engine name: 168.0HP 2.4L 4 Cylinder Engine Gasoline Fuel, engine name: 5.3L V8 16V MPFI OHV Flexible Fuel, engine name: 3.2L V6 18V MPFI SOHC, engine name: 3.8L H6 24V MPFI DOHC, engine name: 245.0HP 2.5L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 6.0L V8 16V MPFI OHV Flexible Fuel, engine name: 2.5L, engine name: 4.7L 8 Cylinder Engine Gasoline Fuel, engine name: 5.7 Liter, engine name: 8.0L W16 64V GDI DOHC Twin Turbo, engine name: 1.4L I4 16V GDI DOHC Turbo, engine name: 6.4L V8 32V DDI OHV Twin Turbo Diesel
# ('accident', 'price'): presenti in 138 engines -> engine name: 2.0L I4 16V PDI DOHC Turbo, engine name: 190.0HP 2.8L Straight 6 Cylinder Engine Gasoline Fuel, engine name: 340.0HP 8.1L 8 Cylinder Engine Gasoline Fuel, engine name: 139.0HP 1.6L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 316.0HP 6.2L 8 Cylinder Engine Flex Fuel Capability, engine name: 355.0HP 6.0L 8 Cylinder Engine Gasoline Fuel, engine name: 335.0HP 6.6L 8 Cylinder Engine Diesel Fuel, engine name: 261.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 306.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel, engine name: 115.0HP Electric Motor Electric Fuel System, engine name: 420.0HP 4.8L 8 Cylinder Engine Gasoline Fuel, engine name: 2.4L H4 16V GDI DOHC Turbo, engine name: 193.0HP 2.5L 4 Cylinder Engine Gasoline Fuel, engine name: 271.0HP 2.4L 4 Cylinder Engine Gasoline Fuel, engine name: 3.6L V6 GDI DOHC, engine name: 197.0HP 3.8L V6 Cylinder Engine Gasoline Fuel, engine name: 2.0L I4 16V GDI DOHC Flexible Fuel, engine name: 450.0HP 4.5L 8 Cylinder Engine Gasoline Fuel, engine name: 5.4 Liter, engine name: 305.0HP 5.7L 8 Cylinder Engine Gasoline Fuel, engine name: 2.5L I4 16V MPFI DOHC Hybrid, engine name: 326.0HP 5.4L 12 Cylinder Engine Gasoline Fuel, engine name: 250.0HP 2.7L V6 Cylinder Engine Gasoline Fuel, engine name: 340.0HP 3.0L V6 Cylinder Engine Flex Fuel Capability, engine name: 212.0HP 1.5L 4 Cylinder Engine Plug-In Electric-Gas, engine name: 370.0HP 5.7L 8 Cylinder Engine Gasoline Fuel, engine name: 153.0HP 1.4L 4 Cylinder Engine Gasoline Fuel, engine name: 260.0HP 3.0L V6 Cylinder Engine Diesel Fuel, engine name: 212.0HP 2.0L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 3.2L V6 18V MPFI SOHC, engine name: 258.0HP 3.2L V6 Cylinder Engine Gasoline Fuel, engine name: 206.0HP 2.4L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 176.0HP 2.5L 4 Cylinder Engine Gasoline Fuel, engine name: 174.0HP 1.5L 4 Cylinder Engine Gasoline Fuel, engine name: 235.0HP 4.7L 8 Cylinder Engine Flex Fuel Capability, engine name: 360.0HP 3.5L V6 Cylinder Engine Gas-Electric Hybrid, engine name: 150.0HP 2.7L 4 Cylinder Engine Gasoline Fuel, engine name: 255.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 525.0HP 5.2L 10 Cylinder Engine Gasoline Fuel, engine name: 2.5L 4 Cylinder Engine Gasoline Fuel, engine name: 240.0HP 2.5L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 205.0HP 3.8L V6 Cylinder Engine Gasoline Fuel, engine name: 164.0HP 1.4L 4 Cylinder Engine Gasoline Fuel, engine name: 362.0HP 3.0L Straight 6 Cylinder Engine Gasoline-Mild Electric Hybrid, engine name: 180.0HP 6.5L 8 Cylinder Engine Diesel Fuel, engine name: 3.2L V6 24V MPFI DOHC, engine name: 521.0HP 4.0L 8 Cylinder Engine Gasoline Fuel, engine name: 266.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 197.0HP 1.6L 4 Cylinder Engine Gasoline Fuel, engine name: 288.0HP 2.0L 4 Cylinder Engine Plug-In Electric-Gas, engine name: 208.0HP 2.0L 4 Cylinder Engine Flex Fuel Capability, engine name: 261.0HP 1.6L 4 Cylinder Engine Plug-In Electric-Gas, engine name: 134.0HP 1.5L 3 Cylinder Engine Gasoline Fuel, engine name: 322.0HP 2.0L 4 Cylinder Engine Plug-In Electric-Gas, engine name: 260.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel, engine name: 235.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 253.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 255.0HP 4.8L 8 Cylinder Engine Gasoline Fuel, engine name: 170.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 295.0HP Electric Motor Electric Fuel System, engine name: 172.0HP 2.4L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 154.0HP 2.7L 5 Cylinder Engine Diesel Fuel, engine name: 375.0HP 5.6L 8 Cylinder Engine Gasoline Fuel, engine name: 360.0HP 4.2L 8 Cylinder Engine Gasoline Fuel, engine name: 279.0HP 3.5L V6 Cylinder Engine Gasoline Fuel, engine name: 3.8L H6 24V MPFI DOHC, engine name: 180.0HP 2.4L 4 Cylinder Engine Flex Fuel Capability, engine name: 4.7L 8 Cylinder Engine Gasoline  ...
# ('clean_title', 'price'): presenti in 44 engines -> engine name: 2.0L I4 16V GDI DOHC Turbo Flexible Fuel, engine name: 390.0HP 4.2L 8 Cylinder Engine Gasoline Fuel, engine name: 139.0HP 1.6L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 4.0 Liter, engine name: 311.0HP 3.8L V6 Cylinder Engine Gasoline Fuel, engine name: 205.0HP 3.8L V6 Cylinder Engine Gasoline Fuel, engine name: 360.0HP 4.6L 8 Cylinder Engine Gasoline Fuel, engine name: 115.0HP Electric Motor Electric Fuel System, engine name: 2.9 Liter Turbo, engine name: 715.0HP 5.2L 12 Cylinder Engine Gasoline Fuel, engine name: 153.0HP 2.3L 4 Cylinder Engine Gasoline Fuel, engine name: 120 AH, engine name: 111.2Ah - FR 70kW - RR 160kW (697V), engine name: 2.0L I4 16V GDI DOHC Hybrid, engine name: 350.0HP 2.5L 4 Cylinder Engine Gasoline Fuel, engine name: 3.4L H6 24V MPFI DOHC, engine name: 134.0HP 1.5L 3 Cylinder Engine Gasoline Fuel, engine name: 1.6L I4 16V GDI DOHC, engine name: 3.2L H6 24V MPFI DOHC, engine name: 320.0HP 3.6L Flat 6 Cylinder Engine Gasoline Fuel, engine name: 247.0HP 2.0L 4 Cylinder Engine Gasoline-Mild Electric Hybrid, engine name: 225.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel, engine name: 326.0HP 5.4L 12 Cylinder Engine Gasoline Fuel, engine name: 3.8L V6 12V MPFI OHV, engine name: 1.5L I3 12V GDI DOHC Turbo, engine name: 710.0HP 4.0L 8 Cylinder Engine Gasoline Fuel, engine name: 552.0HP 6.0L 12 Cylinder Engine Flex Fuel Capability, engine name: 582.0HP 6.0L 12 Cylinder Engine Gasoline Fuel, engine name: 3.4L V6 24V PDI DOHC Twin Turbo Hybrid, engine name: 2.0 Liter Supercharged, engine name: 370.0HP 5.7L 8 Cylinder Engine Gasoline Fuel, engine name: 5.3L V8 16V MPFI OHV Flexible Fuel, engine name: 245.0HP 2.5L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 3.8L H6 24V MPFI DOHC, engine name: Intercooled Turbo Premium Unleaded I-4 2.0 L-122, engine name: 138.0HP 1.6L 4 Cylinder Engine Gasoline Fuel, engine name: 174.0HP 1.5L 4 Cylinder Engine Gasoline Fuel, engine name: 4.7L 8 Cylinder Engine Gasoline Fuel, engine name: 151.0HP Electric Motor Hydrogen Fuel, engine name: 235.0HP 2.0L 4 Cylinder Engine Gasoline Fuel, engine name: 12 Cylinder Engine, engine name: 1.4L I4 16V GDI DOHC Turbo, engine name: 6.4L V8 32V DDI OHV Twin Turbo Diesel, engine name: 475.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel
# ('clean_title', 'milage'): presenti in 39 engines -> engine name: 6.2L V8 32V MPFI DOHC, engine name: 580.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel, engine name: 245.0HP 2.7L Flat 6 Cylinder Engine Gasoline Fuel, engine name: 4.2L V8 32V GDI DOHC, engine name: 6.2 Liter, engine name: 1.6L I4 16V GDI DOHC Hybrid, engine name: 139.0HP 1.6L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 602.0HP 5.2L 10 Cylinder Engine Gasoline Fuel, engine name: 3.8L V6 24V MPFI DOHC Twin Turbo, engine name: 1.3L I3 12V MPFI DOHC Turbo, engine name: 4.4 Liter, engine name: 5.8L V8 32V MPFI DOHC Supercharged, engine name: 115.0HP Electric Motor Electric Fuel System, engine name: 430.0HP 3.8L Flat 6 Cylinder Engine Gasoline Fuel, engine name: 160.0HP 1.4L 4 Cylinder Engine Gasoline Fuel, engine name: 120 AH, engine name: 557.0HP 5.0L 8 Cylinder Engine Gasoline Fuel, engine name: 5.4 Liter, engine name: 3.0L V6 24V PDI DOHC Twin Turbo, engine name: 134.0HP 1.5L 3 Cylinder Engine Gasoline Fuel, engine name: 3.8L V8 32V GDI DOHC Twin Turbo, engine name: 1.6L I4 16V GDI DOHC, engine name: 1.5L I3 12V GDI DOHC Turbo, engine name: 400.0HP 3.6L V6 Cylinder Engine Gasoline Fuel, engine name: 5.4 Liter SC DOHC, engine name: 6.0L V8 16V MPFI OHV, engine name: 295.0HP Electric Motor Electric Fuel System, engine name: 385.0HP 6.7L Straight 6 Cylinder Engine Diesel Fuel, engine name: 2.4L I4 16V MPFI DOHC, engine name: 2.7L I4 16V GDI DOHC Turbo, engine name: 142.0HP 1.8L 4 Cylinder Engine Gasoline Fuel, engine name: 245.0HP 2.5L 4 Cylinder Engine Gas-Electric Hybrid, engine name: 325.0HP 3.7L V6 Cylinder Engine Gasoline Fuel, engine name: 2.5L, engine name: 281.0HP 2.5L 4 Cylinder Engine Gasoline Fuel, engine name: 4.7L 8 Cylinder Engine Gasoline Fuel, engine name: 8.0L W16 64V GDI DOHC Twin Turbo, engine name: 1.4L I4 16V GDI DOHC Turbo, engine name: 6.4L V8 32V DDI OHV Twin Turbo Diesel
#
#
# ---------------------
#
#
# Correlazioni presenti in 2 o più fuels:
# ('milage', 'model_year'): presenti in 8 fuels -> fuel_type name: –, fuel_type name: E85 Flex Fuel, fuel_type name: Plug-In Hybrid, fuel_type name: not supported, fuel_type name: Gasoline, fuel_type name: Hybrid, fuel_type name: -1, fuel_type name: Diesel
# ('accident', 'milage'): presenti in 3 fuels -> fuel_type name: Hybrid, fuel_type name: Plug-In Hybrid, fuel_type name: Gasoline
# ('model_year', 'price'): presenti in 3 fuels -> fuel_type name: Hybrid, fuel_type name: not supported, fuel_type name: Plug-In Hybrid
# ('milage', 'price'): presenti in 3 fuels -> fuel_type name: Hybrid, fuel_type name: not supported, fuel_type name: Plug-In Hybrid
# ('accident', 'clean_title'): presenti in 2 fuels -> fuel_type name: –, fuel_type name: Diesel
#
#
# ---------------------
#
#
# Correlazioni presenti in 2 o più transmissions:
# ('milage', 'model_year'): presenti in 42 transmissions -> transmission name: 1-Speed Automatic, transmission name: 7-Speed M-T, transmission name: 6-Speed M-T, transmission name: 8-SPEED A-T, transmission name: 6-Speed, transmission name: F, transmission name: 5-Speed A-T, transmission name: 8-Speed Automatic with Auto-Shift, transmission name: 7-Speed Manual, transmission name: 6-Speed Automatic with Auto-Shift, transmission name: CVT Transmission, transmission name: 7-Speed Automatic, transmission name: Variable, transmission name: 2-Speed A-T, transmission name: 6 Speed Mt, transmission name: 10-Speed A-T, transmission name: 4-Speed Automatic, transmission name: 6 Speed At-Mt, transmission name: 8-Speed Automatic, transmission name: 10-Speed Automatic, transmission name: Automatic CVT, transmission name: 6-Speed Manual, transmission name: M-T, transmission name: 6-Speed A-T, transmission name: 2, transmission name: 2-Speed Automatic, transmission name: 6-Speed Automatic, transmission name: A-T, transmission name: 8-Speed Manual, transmission name: 9-Speed A-T, transmission name: 8-SPEED AT, transmission name: 10-Speed Automatic with Overdrive, transmission name: 7-Speed A-T, transmission name: CVT-F, transmission name: 1-Speed A-T, transmission name: Automatic, transmission name: 8-Speed A-T, transmission name: 7-Speed DCT Automatic, transmission name: 9-Speed Automatic, transmission name: 7-Speed Automatic with Auto-Shift, transmission name: Transmission w-Dual Shift Mode, transmission name: –
# ('model_year', 'price'): presenti in 17 transmissions -> transmission name: 1-Speed A-T, transmission name: Variable, transmission name: 2-Speed A-T, transmission name: 9-Speed Automatic with Auto-Shift, transmission name: 6 Speed Mt, transmission name: M-T, transmission name: 7-Speed DCT Automatic, transmission name: 8-SPEED A-T, transmission name: SCHEDULED FOR OR IN PRODUCTION, transmission name: 6-Speed, transmission name: A-T, transmission name: 6 Speed At-Mt, transmission name: CVT-F, transmission name: Transmission Overdrive Switch, transmission name: 6-Speed Electronically Controlled Automatic with O, transmission name: 6-Speed Automatic with Auto-Shift, transmission name: CVT Transmission
# ('accident', 'milage'): presenti in 8 transmissions -> transmission name: 2-Speed A-T, transmission name: 6 Speed Mt, transmission name: 7-Speed DCT Automatic, transmission name: 2-Speed Automatic, transmission name: A-T, transmission name: 6 Speed At-Mt, transmission name: 9-Speed Automatic with Auto-Shift, transmission name: Manual
# ('milage', 'price'): presenti in 16 transmissions -> transmission name: 1-Speed A-T, transmission name: Variable, transmission name: 2-Speed A-T, transmission name: 6 Speed Mt, transmission name: M-T, transmission name: 2-Speed Automatic, transmission name: 8-SPEED A-T, transmission name: 6-Speed, transmission name: A-T, transmission name: 6 Speed At-Mt, transmission name: CVT-F, transmission name: Transmission Overdrive Switch, transmission name: 7-Speed Manual, transmission name: 6-Speed Automatic with Auto-Shift, transmission name: CVT Transmission, transmission name: Manual
# ('accident', 'clean_title'): presenti in 10 transmissions -> transmission name: 1-Speed A-T, transmission name: M-T, transmission name: 7-Speed M-T, transmission name: 8-Speed A-T, transmission name: 2-Speed Automatic, transmission name: 7-Speed DCT Automatic, transmission name: 10-Speed A-T, transmission name: F, transmission name: 7-Speed A-T, transmission name: Manual
# ('accident', 'model_year'): presenti in 6 transmissions -> transmission name: 2-Speed A-T, transmission name: 6 Speed Mt, transmission name: 7-Speed DCT Automatic, transmission name: 2-Speed Automatic, transmission name: 8-SPEED AT, transmission name: F
# ('accident', 'price'): presenti in 3 transmissions -> transmission name: 2-Speed A-T, transmission name: 7-Speed, transmission name: CVT-F
# ('clean_title', 'model_year'): presenti in 9 transmissions -> transmission name: Single-Speed Fixed Gear, transmission name: 2, transmission name: 8-SPEED A-T, transmission name: 7-Speed, transmission name: 6-Speed, transmission name: 10-Speed Automatic with Overdrive, transmission name: F, transmission name: SCHEDULED FOR OR IN PRODUCTION, transmission name: Manual
# ('clean_title', 'milage'): presenti in 3 transmissions -> transmission name: 7-Speed DCT Automatic, transmission name: 2-Speed Automatic, transmission name: 10-Speed Automatic with Overdrive
# ('clean_title', 'price'): presenti in 4 transmissions -> transmission name: 8-SPEED AT, transmission name: 8-SPEED A-T, transmission name: SCHEDULED FOR OR IN PRODUCTION, transmission name: Single-Speed Fixed Gear
#
#
# ---------------------

# %%
def barplots_corr(relevant_correlations, nome_lista):
    pairs = []
    occurrences = []
    for pair, element in relevant_correlations.items():
        pairs.append(f"{pair[0]} - {pair[1]}")
        occurrences.append(len(element))

    # Visualizzazione con Matplotlib e Seaborn
    plt.figure(figsize=(12, 8))
    sns.barplot(x=occurrences, y=pairs, palette="viridis")
    plt.xlabel(f"Numero di {nome_lista}")
    plt.ylabel("Coppie di colonne")
    plt.title("Coppie di colonne con correlazioni presenti in almeno 2 brand")
    plt.tight_layout()
    plt.show()


barplots_corr(relevant_correlations_brands,"brands")
print("\n\n---------------------\n\n")
barplots_corr(relevant_correlations_engines,"engines")
print("\n\n---------------------\n\n")
barplots_corr(relevant_correlations_fuels,"fuels")
print("\n\n---------------------\n\n")
barplots_corr(relevant_correlations_trans,"trans")
# Out:
# /tmp/ipykernel_58305/4072340198.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=occurrences, y=pairs, palette="viridis")
# ---------------------
# /tmp/ipykernel_58305/4072340198.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=occurrences, y=pairs, palette="viridis")
# ---------------------
# /tmp/ipykernel_58305/4072340198.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=occurrences, y=pairs, palette="viridis")
# ---------------------
# /tmp/ipykernel_58305/4072340198.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=occurrences, y=pairs, palette="viridis")

# %%
def heatmap_corr(relevant_correlations, nome_lista):

    pairs = []
    occurrences = []
    for pair, element in relevant_correlations.items():
        pairs.append(f"{pair[0]} - {pair[1]}")
        occurrences.append(len(element))
    
    heatmap_data = pd.DataFrame(index=pairs, columns=list({el for elements in relevant_correlations.values() for el in elements}))
    for pair, elements in relevant_correlations.items():
        row_label = f"{pair[0]} - {pair[1]}"
        for el in elements:
            heatmap_data.at[row_label, el] = 1


    heatmap_data = heatmap_data.fillna(0)

    # Plot della heatmap
    plt.figure(figsize=(14, 10))
    sns.heatmap(heatmap_data, annot=True, cmap="coolwarm", cbar=True)
    plt.title(f"Mappa dei {nome_lista} per coppie di colonne con correlazioni significative")
    plt.xlabel(f"{nome_lista}")
    plt.ylabel("Coppie di colonne")
    plt.tight_layout()
    plt.show()


heatmap_corr(relevant_correlations_brands, "brands")
print("\n\n---------------------\n\n")
heatmap_corr(relevant_correlations_engines,"engines")
print("\n\n---------------------\n\n")
# Out:
# /tmp/ipykernel_58305/998289181.py:16: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   heatmap_data = heatmap_data.fillna(0)
# ---------------------
# /tmp/ipykernel_58305/998289181.py:16: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   heatmap_data = heatmap_data.fillna(0)
# ---------------------

# %%
heatmap_corr(relevant_correlations_fuels,"fuels")
print("\n\n---------------------\n\n")
heatmap_corr(relevant_correlations_trans,"trans")
# Out:
# /tmp/ipykernel_58305/998289181.py:16: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   heatmap_data = heatmap_data.fillna(0)
# ---------------------
# /tmp/ipykernel_58305/998289181.py:16: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   heatmap_data = heatmap_data.fillna(0)
